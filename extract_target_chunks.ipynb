# %% [markdown]
# <a href="https://colab.research.google.com/github/noahdanieldsouza/PAM-classification/blob/main/extract_target_chunks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install soundfile librosa

# %%
import librosa
import soundfile as sf
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# ==== Configuration ====
input_path = '/content/drive/MyDrive/mass_data/8567.240729135951.wav'

start_time = 6510  # in seconds
end_time = 6540    # in seconds

y, sr = librosa.load(input_path, sr=None, offset=start_time, duration=end_time - start_time)

output_path = '/content/drive/MyDrive/test2.wav'
sf.write(output_path, y, sr)
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# === Parameters ===
input_path ='/content/drive/MyDrive/mass_data/8567.240730165948.wav' # your 3-hour file
output_dir ='/content/drive/MyDrive/mass_data/cut2'         # folder to save chunks
chunk_duration = 5  # seconds

# Create output folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# === Load the entire audio file ===
y, sr = librosa.load(input_path, sr=None)
total_duration = librosa.get_duration(y=y, sr=sr)
samples_per_chunk = int(chunk_duration * sr)

print(f"Loaded file: {input_path}")
print(f"Total duration: {total_duration / 60:.2f} minutes")
print(f"Saving 5-second chunks to: {output_dir}")

# === Split and save ===
for i in range(0, len(y), samples_per_chunk):
    chunk = y[i:i + samples_per_chunk]

    start_sec = i / sr
    end_sec = min((i + samples_per_chunk) / sr, total_duration)

    filename = f"2.10chunk_{int(start_sec):06d}_{int(end_sec):06d}.wav"
    out_path = os.path.join(output_dir, filename)

    sf.write(out_path, chunk, sr)
    print(f"Saved: {filename}")

print("\n✅ All chunks saved.")
# Out:
# Mounted at /content/drive
# Loaded file: /content/drive/MyDrive/mass_data/8567.240730165948.wav
# Total duration: 179.97 minutes
# Saving 5-second chunks to: /content/drive/MyDrive/mass_data/cut2
# Saved: 2.10chunk_000000_000005.wav
# Saved: 2.10chunk_000005_000010.wav
# Saved: 2.10chunk_000010_000015.wav
# Saved: 2.10chunk_000015_000020.wav
# Saved: 2.10chunk_000020_000025.wav
# Saved: 2.10chunk_000025_000030.wav
# Saved: 2.10chunk_000030_000035.wav
# Saved: 2.10chunk_000035_000040.wav
# Saved: 2.10chunk_000040_000045.wav
# Saved: 2.10chunk_000045_000050.wav
# Saved: 2.10chunk_000050_000055.wav
# Saved: 2.10chunk_000055_000060.wav
# Saved: 2.10chunk_000060_000065.wav
# Saved: 2.10chunk_000065_000070.wav
# Saved: 2.10chunk_000070_000075.wav
# Saved: 2.10chunk_000075_000080.wav
# Saved: 2.10chunk_000080_000085.wav
# Saved: 2.10chunk_000085_000090.wav
# Saved: 2.10chunk_000090_000095.wav
# Saved: 2.10chunk_000095_000100.wav
# Saved: 2.10chunk_000100_000105.wav
# ...
