# %% [markdown]
# <a href="https://colab.research.google.com/github/noahdanieldsouza/PAM-classification/blob/main/audio_cut_frequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install Libraries { vertical-output: true }
# !pip install pydub librosa numpy scipy
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy_loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.6.15)

# %%
#@title Imports { vertical-output: true }
import os
import xml.etree.ElementTree as ET
from pydub import AudioSegment
import numpy as np
import librosa
import soundfile as sf
from datetime import datetime, timedelta

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# ==== Configuration ====
WAV_PATH = '/content/drive/MyDrive/lake-sounds/8567.240831110000.wav'
OUTPUT_CLIP_DIR = '/content/drive/MyDrive/lake-sounds/clips'
CLIP_LENGTH_SECONDS = 5.0

# Spectral thresholds (tune as needed)
BOAT_CENTROID_MIN = 9000  #@param {type:'int'} # minimum frequency of boat noise
BOAT_CENTROID_MAX = 12000  #@param {type:'int'} # maximum frequency of boat noise
BOAT_BW_MIN       = 11000 #@param {type:'int'} # minimum bandwidth of boat noise
BOAT_BW_MAX       = 12500  #@param {type:'int'} # maximum bandwidth of boat noise
CHUNK_DURATION = 1.0  # seconds  #@param {type:'int'} #length of audio analyzed
MIN_EVENT_DURATION = 0.75  # seconds
OVERLAP = 0.5
SAMPLE_RATE = None  # use original
# Out:
# Mounted at /content/drive

# %%
import xml.etree.ElementTree as ET
from datetime import datetime, timedelta

# Load base time from XML
def parse_xml_time(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    for proc_event in root.findall(".//PROC_EVENT"):
        wav_handler = proc_event.find("WavFileHandler")
        if wav_handler is not None:
            start_time_str = wav_handler.attrib.get("SamplingStartTimeLocal")
            if start_time_str:
                return datetime.fromisoformat(start_time_str)
    raise ValueError("SamplingStartTimeLocal not found")

# Write XML file for clip
def write_xml_for_clip(base_datetime, clip_start, output_path):
    clip_time = base_datetime + timedelta(seconds=clip_start)
    clip_time_str = clip_time.isoformat()
    root = ET.Element("ST")
    proc_event = ET.SubElement(root, "PROC_EVENT", attrib={"ID": "4"})
    ET.SubElement(proc_event, "WavFileHandler", attrib={
        "SamplingStartTimeLocal": clip_time_str
    })
    tree = ET.ElementTree(root)
    tree.write(output_path)

# %%
os.makedirs(OUTPUT_CLIP_DIR, exist_ok=True)
# ==== Load audio ====
y, sr = librosa.load(WAV_PATH, sr=SAMPLE_RATE)
duration_sec = librosa.get_duration(y=y, sr=sr)
samples_per_chunk = int(CHUNK_DURATION * sr)

print(f"Loaded audio: {WAV_PATH}")
print(f"Duration: {duration_sec/60:.2f} minutes, Sample rate: {sr}, Total samples: {len(y)}")

# ==== Event Detection ====
event_times = []
in_event = False
event_start = None

hop = int((CHUNK_DURATION - OVERLAP) * sr)

for i in range(0, len(y) - samples_per_chunk, hop):
    chunk = y[i:i+samples_per_chunk]
    if len(chunk) < samples_per_chunk:
        break

    centroid = librosa.feature.spectral_centroid(y=chunk, sr=sr).mean()
    bandwidth = librosa.feature.spectral_bandwidth(y=chunk, sr=sr).mean()

    t_start = i / sr
    t_end = (i + samples_per_chunk) / sr

    is_boat = (BOAT_CENTROID_MIN  <= centroid <= BOAT_CENTROID_MAX) \
           and (BOAT_BW_MIN       <= bandwidth <= BOAT_BW_MAX)

    if is_boat:
      print(f"[DETECTED] {t_start:.2f}s → Centroid: {centroid:.2f} Hz, Bandwidth: {bandwidth:.2f} Hz")


    if not is_boat:
        if not in_event:
            event_start = t_start
            in_event = True
    else:
        if in_event:
            if t_end - event_start >= MIN_EVENT_DURATION:
                event_times.append((event_start, t_end))
            in_event = False

if in_event:
    if duration_sec - event_start >= MIN_EVENT_DURATION:
        event_times.append((event_start, duration_sec))

print(f"Detected {len(event_times)} events")

# ==== Clip Saving Function ====
def save_clip(y, sr, start_sec, clip_index):
    clip_start = int(start_sec * sr)
    clip_end = clip_start + int(CLIP_LENGTH_SECONDS * sr)

    if clip_end > len(y):
        clip_end = len(y)

    clip = y[clip_start:clip_end]

    timestamp = str(timedelta(seconds=int(start_sec))).replace(":", "-")
    filename = f"clip_{clip_index:03}_{timestamp}.wav"
    out_path = os.path.join(OUTPUT_CLIP_DIR, filename)

    sf.write(out_path, clip, sr)
    return out_path

# ==== Extract & Save Clips ====
saved_clips = []
base_xml_path = WAV_PATH.replace(".wav", ".log.xml")
base_datetime = parse_xml_time(base_xml_path)
for idx, (start_sec, end_sec) in enumerate(event_times):
    center_time = (start_sec + end_sec) / 2.0
    clip_start = max(0, center_time - CLIP_LENGTH_SECONDS / 2.0)
    clip_path = save_clip(y, sr, clip_start, idx)

    # XML output path
    clip_filename = os.path.basename(clip_path)
    xml_filename = clip_filename.replace(".wav", ".xml")
    xml_path = os.path.join(OUTPUT_CLIP_DIR, xml_filename)

    # Write XML
    write_xml_for_clip(base_datetime, clip_start, xml_path)

    saved_clips.append((clip_path, xml_path, clip_start))

print(f"Saved {len(saved_clips)} 5-second clips and XMLs to {OUTPUT_CLIP_DIR}")
# Out:
# Streaming output truncated to the last 5000 lines.
# [DETECTED] 1189.50s → Centroid: 11841.11 Hz, Bandwidth: 11527.79 Hz
# [DETECTED] 1190.00s → Centroid: 11366.92 Hz, Bandwidth: 11425.74 Hz
# [DETECTED] 1190.50s → Centroid: 11406.97 Hz, Bandwidth: 11409.60 Hz
# [DETECTED] 1191.00s → Centroid: 11855.14 Hz, Bandwidth: 11409.21 Hz
# [DETECTED] 1192.00s → Centroid: 11490.66 Hz, Bandwidth: 11458.96 Hz
# [DETECTED] 1192.50s → Centroid: 11518.23 Hz, Bandwidth: 11451.66 Hz
# [DETECTED] 1193.50s → Centroid: 11796.61 Hz, Bandwidth: 11457.00 Hz
# [DETECTED] 1194.00s → Centroid: 11599.15 Hz, Bandwidth: 11464.42 Hz
# [DETECTED] 1195.00s → Centroid: 11201.59 Hz, Bandwidth: 11319.58 Hz
# [DETECTED] 1195.50s → Centroid: 11107.11 Hz, Bandwidth: 11552.62 Hz
# [DETECTED] 1196.00s → Centroid: 11930.75 Hz, Bandwidth: 11677.16 Hz
# [DETECTED] 1197.50s → Centroid: 11936.58 Hz, Bandwidth: 11745.76 Hz
# [DETECTED] 1199.00s → Centroid: 11849.34 Hz, Bandwidth: 11716.76 Hz
# [DETECTED] 1200.00s → Centroid: 11953.40 Hz, Bandwidth: 11683.19 Hz
# [DETECTED] 1200.50s → Centroid: 11889.59 Hz, Bandwidth: 11720.09 Hz
# [DETECTED] 1216.50s → Centroid: 11960.84 Hz, Bandwidth: 11967.85 Hz
# [DETECTED] 1217.00s → Centroid: 11941.46 Hz, Bandwidth: 12050.53 Hz
# [DETECTED] 1218.00s → Centroid: 11729.14 Hz, Bandwidth: 11981.56 Hz
# [DETECTED] 1218.50s → Centroid: 11670.91 Hz, Bandwidth: 11871.83 Hz
# [DETECTED] 1219.50s → Centroid: 11810.45 Hz, Bandwidth: 11942.29 Hz
# [DETECTED] 1220.00s → Centroid: 11644.81 Hz, Bandwidth: 11952.76 Hz
# [DETECTED] 1220.50s → Centroid: 11970.49 Hz, Bandwidth: 11876.47 Hz
# [DETECTED] 1221.00s → Centroid: 11366.93 Hz, Bandwidth: 11756.71 Hz
# [DETECTED] 1221.50s → Centroid: 11408.11 Hz, Bandwidth: 11774.51 Hz
# [DETECTED] 1222.00s → Centroid: 11910.20 Hz, Bandwidth: 11831.82 Hz
# [DETECTED] 1222.50s → Centroid: 11555.46 Hz, Bandwidth: 11803.67 Hz
# [DETECTED] 1223.00s → Centroid: 11440.45 Hz, Bandwidth: 11872.17 Hz
# [DETECTED] 1223.50s → Centroid: 11928.31 Hz, Bandwidth: 11954.06 Hz
# [DETECTED] 1224.50s → Centroid: 11356.27 Hz, Bandwidth: 11899.67 Hz
# [DETECTED] 1225.00s → Centroid: 11400.71 Hz, Bandwidth: 11834.05 Hz
# [DETECTED] 1225.50s → Centroid: 11960.78 Hz, Bandwidth: 11906.75 Hz
# [DETECTED] 1226.00s → Centroid: 11559.46 Hz, Bandwidth: 11873.78 Hz
# [DETECTED] 1226.50s → Centroid: 11486.13 Hz, Bandwidth: 11885.97 Hz
# [DETECTED] 1227.00s → Centroid: 11611.09 Hz, Bandwidth: 11853.99 Hz
# [DETECTED] 1227.50s → Centroid: 11093.41 Hz, Bandwidth: 11767.98 Hz
# [DETECTED] 1228.00s → Centroid: 11369.37 Hz, Bandwidth: 11917.63 Hz
# [DETECTED] 1228.50s → Centroid: 11718.06 Hz, Bandwidth: 12087.59 Hz
# [DETECTED] 1229.00s → Centroid: 11415.66 Hz, Bandwidth: 12109.33 Hz
# [DETECTED] 1229.50s → Centroid: 11451.69 Hz, Bandwidth: 12100.63 Hz
# [DETECTED] 1230.00s → Centroid: 11229.01 Hz, Bandwidth: 12054.26 Hz
# [DETECTED] 1230.50s → Centroid: 11002.95 Hz, Bandwidth: 11946.77 Hz
# [DETECTED] 1231.00s → Centroid: 11536.33 Hz, Bandwidth: 11958.16 Hz
# [DETECTED] 1231.50s → Centroid: 11654.63 Hz, Bandwidth: 12122.86 Hz
# [DETECTED] 1232.00s → Centroid: 11402.96 Hz, Bandwidth: 12200.81 Hz
# [DETECTED] 1232.50s → Centroid: 11628.09 Hz, Bandwidth: 12175.40 Hz
# [DETECTED] 1233.00s → Centroid: 11558.68 Hz, Bandwidth: 12081.63 Hz
# [DETECTED] 1233.50s → Centroid: 11513.26 Hz, Bandwidth: 12148.03 Hz
# [DETECTED] 1234.00s → Centroid: 11742.66 Hz, Bandwidth: 12214.49 Hz
# [DETECTED] 1234.50s → Centroid: 11418.96 Hz, Bandwidth: 12113.77 Hz
# [DETECTED] 1235.00s → Centroid: 11340.43 Hz, Bandwidth: 12071.00 Hz
# [DETECTED] 1235.50s → Centroid: 11651.69 Hz, Bandwidth: 12122.10 Hz
# [DETECTED] 1236.00s → Centroid: 11541.21 Hz, Bandwidth: 12176.70 Hz
# [DETECTED] 1236.50s → Centroid: 11466.62 Hz, Bandwidth: 12230.73 Hz
# [DETECTED] 1237.00s → Centroid: 11381.23 Hz, Bandwidth: 12218.17 Hz
# [DETECTED] 1237.50s → Centroid: 11076.92 Hz, Bandwidth: 12180.65 Hz
# [DETECTED] 1238.00s → Centroid: 11075.85 Hz, Bandwidth: 12209.11 Hz
# [DETECTED] 1238.50s → Centroid: 11382.24 Hz, Bandwidth: 12292.06 Hz
# [DETECTED] 1239.00s → Centroid: 11448.71 Hz, Bandwidth: 12299.28 Hz
# [DETECTED] 1239.50s → Centroid: 11146.32 Hz, Bandwidth: 12223.11 Hz
# [DETECTED] 1240.00s → Centroid: 11105.23 Hz, Bandwidth: 12212.82 Hz
# [DETECTED] 1240.50s → Centroid: 11131.35 Hz, Bandwidth: 12220.60 Hz
# [DETECTED] 1241.00s → Centroid: 10807.80 Hz, Bandwidth: 12182.74 Hz
# [DETECTED] 1241.50s → Centroid: 11085.37 Hz, Bandwidth: 12268.92 Hz
# [DETECTED] 1242.00s → Centroid: 11326.96 Hz, Bandwidth: 12357.91 Hz
# [DETECTED] 1242.50s → Centroid: 11149.90 Hz, Bandwidth: 12401.33 Hz
# [DETECTED] 1243.50s → Centroid: 11187.37 Hz, Bandwidth: 12457.31 Hz
# [DETECTED] 1244.00s → Centroid: 10976.68 Hz, Bandwidth: 12362.05 Hz
# [DETECTED] 1249.50s → Centroid: 10804.33 Hz, Bandwidth: 12330.03 Hz
# [DETECTED] 1250.00s → Centroid: 10701.41 Hz, Bandwidth: 12263.69 Hz
# [DETECTED] 1269.00s → Centroid: 11886.09 Hz, Bandwidth: 12401.14 Hz
# [DETECTED] 1269.50s → Centroid: 11784.11 Hz, Bandwidth: 12356.96 Hz
# [DETECTED] 1270.00s → Centroid: 11806.01 Hz, Bandwidth: 12335.43 Hz
# [DETECTED] 1270.50s → Centroid: 11725.12 Hz, Bandwidth: 12295.83 Hz
# [DETECTED] 1271.00s → Centroid: 11704.43 Hz, Bandwidth: 12235.80 Hz
# [DETECTED] 1271.50s → Centroid: 11611.17 Hz, Bandwidth: 12125.66 Hz
# [DETECTED] 1272.00s → Centroid: 11619.55 Hz, Bandwidth: 12070.18 Hz
# [DETECTED] 1272.50s → Centroid: 11780.75 Hz, Bandwidth: 12093.80 Hz
# [DETECTED] 1273.00s → Centroid: 11943.21 Hz, Bandwidth: 12158.99 Hz
# [DETECTED] 1273.50s → Centroid: 11763.77 Hz, Bandwidth: 12167.49 Hz
# [DETECTED] 1274.00s → Centroid: 11404.29 Hz, Bandwidth: 12161.17 Hz
# [DETECTED] 1274.50s → Centroid: 11310.72 Hz, Bandwidth: 12170.08 Hz
# [DETECTED] 1275.00s → Centroid: 11501.30 Hz, Bandwidth: 12235.57 Hz
# [DETECTED] 1275.50s → Centroid: 11684.83 Hz, Bandwidth: 12356.36 Hz
# [DETECTED] 1276.00s → Centroid: 11755.03 Hz, Bandwidth: 12372.10 Hz
# [DETECTED] 1276.50s → Centroid: 11490.64 Hz, Bandwidth: 12341.79 Hz
# [DETECTED] 1277.00s → Centroid: 11299.67 Hz, Bandwidth: 12496.37 Hz
# [DETECTED] 1278.50s → Centroid: 10856.03 Hz, Bandwidth: 12303.93 Hz
# [DETECTED] 1279.00s → Centroid: 10460.89 Hz, Bandwidth: 12210.92 Hz
# [DETECTED] 1279.50s → Centroid: 10236.97 Hz, Bandwidth: 12118.22 Hz
# [DETECTED] 1280.00s → Centroid: 9751.47 Hz, Bandwidth: 11955.40 Hz
# [DETECTED] 1280.50s → Centroid: 9437.42 Hz, Bandwidth: 11926.74 Hz
# [DETECTED] 1281.00s → Centroid: 9440.82 Hz, Bandwidth: 11909.23 Hz
# [DETECTED] 1281.50s → Centroid: 9269.96 Hz, Bandwidth: 11741.25 Hz
# [DETECTED] 1282.00s → Centroid: 9302.57 Hz, Bandwidth: 11650.81 Hz
# [DETECTED] 1282.50s → Centroid: 9066.26 Hz, Bandwidth: 11559.94 Hz
# [DETECTED] 1305.00s → Centroid: 10255.94 Hz, Bandwidth: 11005.44 Hz
# [DETECTED] 1314.00s → Centroid: 10285.41 Hz, Bandwidth: 11107.27 Hz
# [DETECTED] 1314.50s → Centroid: 10993.30 Hz, Bandwidth: 11132.83 Hz
# [DETECTED] 1315.00s → Centroid: 10752.88 Hz, Bandwidth: 11116.53 Hz
# [DETECTED] 1315.50s → Centroid: 10656.07 Hz, Bandwidth: 11221.95 Hz
# [DETECTED] 1316.00s → Centroid: 10775.64 Hz, Bandwidth: 11313.43 Hz
# [DETECTED] 1316.50s → Centroid: 10462.67 Hz, Bandwidth: 11294.85 Hz
# [DETECTED] 1317.00s → Centroid: 10526.07 Hz, Bandwidth: 11304.75 Hz
# [DETECTED] 1317.50s → Centroid: 10204.27 Hz, Bandwidth: 11353.60 Hz
# [DETECTED] 1318.00s → Centroid: 10747.62 Hz, Bandwidth: 11465.59 Hz
# [DETECTED] 1318.50s → Centroid: 11720.99 Hz, Bandwidth: 11557.89 Hz
# [DETECTED] 1319.00s → Centroid: 11559.31 Hz, Bandwidth: 11553.74 Hz
# [DETECTED] 1319.50s → Centroid: 11202.56 Hz, Bandwidth: 11545.27 Hz
# [DETECTED] 1320.00s → Centroid: 10777.28 Hz, Bandwidth: 11551.82 Hz
# [DETECTED] 1320.50s → Centroid: 10626.85 Hz, Bandwidth: 11589.10 Hz
# [DETECTED] 1321.00s → Centroid: 10654.16 Hz, Bandwidth: 11563.98 Hz
# [DETECTED] 1321.50s → Centroid: 10970.47 Hz, Bandwidth: 11564.33 Hz
# [DETECTED] 1322.00s → Centroid: 11556.13 Hz, Bandwidth: 11602.78 Hz
# [DETECTED] 1322.50s → Centroid: 11411.58 Hz, Bandwidth: 11662.15 Hz
# [DETECTED] 1323.00s → Centroid: 10531.08 Hz, Bandwidth: 11648.49 Hz
# [DETECTED] 1323.50s → Centroid: 10548.52 Hz, Bandwidth: 11704.37 Hz
# [DETECTED] 1324.00s → Centroid: 11298.23 Hz, Bandwidth: 11817.80 Hz
# [DETECTED] 1324.50s → Centroid: 11904.46 Hz, Bandwidth: 11902.93 Hz
# [DETECTED] 1328.00s → Centroid: 11882.56 Hz, Bandwidth: 11824.10 Hz
# [DETECTED] 1328.50s → Centroid: 11383.38 Hz, Bandwidth: 11762.86 Hz
# [DETECTED] 1329.00s → Centroid: 11351.82 Hz, Bandwidth: 11747.04 Hz
# [DETECTED] 1329.50s → Centroid: 11286.27 Hz, Bandwidth: 11718.21 Hz
# [DETECTED] 1330.00s → Centroid: 11946.37 Hz, Bandwidth: 11925.50 Hz
# [DETECTED] 1331.00s → Centroid: 11013.99 Hz, Bandwidth: 11896.57 Hz
# [DETECTED] 1331.50s → Centroid: 10492.16 Hz, Bandwidth: 11764.22 Hz
# [DETECTED] 1332.00s → Centroid: 10637.79 Hz, Bandwidth: 11668.79 Hz
# [DETECTED] 1332.50s → Centroid: 10870.14 Hz, Bandwidth: 11606.23 Hz
# [DETECTED] 1333.00s → Centroid: 11492.48 Hz, Bandwidth: 11642.91 Hz
# [DETECTED] 1333.50s → Centroid: 11696.68 Hz, Bandwidth: 11660.83 Hz
# [DETECTED] 1334.00s → Centroid: 11662.66 Hz, Bandwidth: 11647.48 Hz
# [DETECTED] 1334.50s → Centroid: 11506.87 Hz, Bandwidth: 11649.88 Hz
# [DETECTED] 1335.00s → Centroid: 11429.06 Hz, Bandwidth: 11617.81 Hz
# [DETECTED] 1335.50s → Centroid: 11528.56 Hz, Bandwidth: 11627.08 Hz
# [DETECTED] 1336.00s → Centroid: 11678.39 Hz, Bandwidth: 11767.99 Hz
# [DETECTED] 1338.50s → Centroid: 11959.61 Hz, Bandwidth: 11596.07 Hz
# [DETECTED] 1339.00s → Centroid: 11480.82 Hz, Bandwidth: 11684.91 Hz
# [DETECTED] 1339.50s → Centroid: 11403.91 Hz, Bandwidth: 11727.01 Hz
# [DETECTED] 1340.00s → Centroid: 11613.08 Hz, Bandwidth: 11649.81 Hz
# [DETECTED] 1340.50s → Centroid: 11807.79 Hz, Bandwidth: 11664.94 Hz
# [DETECTED] 1341.00s → Centroid: 11634.10 Hz, Bandwidth: 11674.48 Hz
# [DETECTED] 1341.50s → Centroid: 11797.46 Hz, Bandwidth: 11643.89 Hz
# [DETECTED] 1342.00s → Centroid: 11763.54 Hz, Bandwidth: 11673.00 Hz
# [DETECTED] 1342.50s → Centroid: 11510.39 Hz, Bandwidth: 11722.20 Hz
# [DETECTED] 1343.00s → Centroid: 11384.58 Hz, Bandwidth: 11754.93 Hz
# [DETECTED] 1343.50s → Centroid: 11266.86 Hz, Bandwidth: 11793.61 Hz
# [DETECTED] 1344.00s → Centroid: 11343.33 Hz, Bandwidth: 11764.98 Hz
# [DETECTED] 1344.50s → Centroid: 11181.44 Hz, Bandwidth: 11647.45 Hz
# [DETECTED] 1345.00s → Centroid: 10955.97 Hz, Bandwidth: 11644.27 Hz
# [DETECTED] 1345.50s → Centroid: 11245.91 Hz, Bandwidth: 11866.19 Hz
# [DETECTED] 1346.00s → Centroid: 11670.67 Hz, Bandwidth: 12028.91 Hz
# [DETECTED] 1346.50s → Centroid: 11561.56 Hz, Bandwidth: 11926.60 Hz
# [DETECTED] 1347.00s → Centroid: 11560.36 Hz, Bandwidth: 11913.31 Hz
# [DETECTED] 1347.50s → Centroid: 11193.96 Hz, Bandwidth: 11901.17 Hz
# [DETECTED] 1348.00s → Centroid: 10746.48 Hz, Bandwidth: 11876.49 Hz
# [DETECTED] 1348.50s → Centroid: 11136.09 Hz, Bandwidth: 11963.91 Hz
# [DETECTED] 1349.00s → Centroid: 11327.77 Hz, Bandwidth: 11966.02 Hz
# [DETECTED] 1349.50s → Centroid: 11461.77 Hz, Bandwidth: 11960.50 Hz
# [DETECTED] 1350.00s → Centroid: 11409.87 Hz, Bandwidth: 11944.69 Hz
# [DETECTED] 1350.50s → Centroid: 10973.45 Hz, Bandwidth: 11804.10 Hz
# [DETECTED] 1351.00s → Centroid: 10763.44 Hz, Bandwidth: 11742.12 Hz
# [DETECTED] 1351.50s → Centroid: 10285.56 Hz, Bandwidth: 11585.11 Hz
# [DETECTED] 1352.00s → Centroid: 9640.19 Hz, Bandwidth: 11328.35 Hz
# [DETECTED] 1352.50s → Centroid: 9317.30 Hz, Bandwidth: 11143.00 Hz
# [DETECTED] 1353.00s → Centroid: 9039.71 Hz, Bandwidth: 11049.98 Hz
# [DETECTED] 1356.50s → Centroid: 10395.19 Hz, Bandwidth: 11063.77 Hz
# [DETECTED] 1357.00s → Centroid: 11447.52 Hz, Bandwidth: 11305.89 Hz
# [DETECTED] 1357.50s → Centroid: 11725.67 Hz, Bandwidth: 11387.06 Hz
# [DETECTED] 1358.00s → Centroid: 11635.14 Hz, Bandwidth: 11332.29 Hz
# [DETECTED] 1358.50s → Centroid: 11784.52 Hz, Bandwidth: 11349.14 Hz
# [DETECTED] 1359.00s → Centroid: 11427.05 Hz, Bandwidth: 11583.55 Hz
# [DETECTED] 1359.50s → Centroid: 10672.68 Hz, Bandwidth: 11855.66 Hz
# [DETECTED] 1360.00s → Centroid: 11003.80 Hz, Bandwidth: 11912.88 Hz
# [DETECTED] 1360.50s → Centroid: 11671.73 Hz, Bandwidth: 11900.16 Hz
# [DETECTED] 1361.00s → Centroid: 11643.19 Hz, Bandwidth: 12140.72 Hz
# [DETECTED] 1361.50s → Centroid: 11498.88 Hz, Bandwidth: 12104.57 Hz
# [DETECTED] 1362.00s → Centroid: 11100.35 Hz, Bandwidth: 11731.17 Hz
# [DETECTED] 1362.50s → Centroid: 10400.61 Hz, Bandwidth: 11649.99 Hz
# [DETECTED] 1363.00s → Centroid: 10253.50 Hz, Bandwidth: 11707.99 Hz
# [DETECTED] 1363.50s → Centroid: 10179.66 Hz, Bandwidth: 11753.28 Hz
# [DETECTED] 1364.00s → Centroid: 10608.87 Hz, Bandwidth: 11955.60 Hz
# [DETECTED] 1364.50s → Centroid: 11272.81 Hz, Bandwidth: 12116.65 Hz
# [DETECTED] 1365.00s → Centroid: 10997.24 Hz, Bandwidth: 12049.76 Hz
# [DETECTED] 1365.50s → Centroid: 10566.59 Hz, Bandwidth: 12061.84 Hz
# [DETECTED] 1366.00s → Centroid: 10352.75 Hz, Bandwidth: 11959.37 Hz
# [DETECTED] 1366.50s → Centroid: 9836.36 Hz, Bandwidth: 11725.70 Hz
# [DETECTED] 1367.00s → Centroid: 9392.66 Hz, Bandwidth: 11557.31 Hz
# [DETECTED] 1367.50s → Centroid: 9524.87 Hz, Bandwidth: 11565.96 Hz
# [DETECTED] 1368.00s → Centroid: 10426.54 Hz, Bandwidth: 11855.06 Hz
# [DETECTED] 1368.50s → Centroid: 11038.65 Hz, Bandwidth: 12014.70 Hz
# [DETECTED] 1369.00s → Centroid: 10962.62 Hz, Bandwidth: 11918.69 Hz
# [DETECTED] 1369.50s → Centroid: 11044.57 Hz, Bandwidth: 11722.03 Hz
# [DETECTED] 1370.00s → Centroid: 11339.45 Hz, Bandwidth: 11647.03 Hz
# [DETECTED] 1371.50s → Centroid: 11670.52 Hz, Bandwidth: 11734.92 Hz
# [DETECTED] 1372.00s → Centroid: 11066.02 Hz, Bandwidth: 11467.81 Hz
# [DETECTED] 1372.50s → Centroid: 11046.66 Hz, Bandwidth: 11552.79 Hz
# [DETECTED] 1373.00s → Centroid: 10909.36 Hz, Bandwidth: 11738.26 Hz
# [DETECTED] 1373.50s → Centroid: 10783.50 Hz, Bandwidth: 11671.13 Hz
# [DETECTED] 1374.00s → Centroid: 11230.63 Hz, Bandwidth: 11385.50 Hz
# [DETECTED] 1374.50s → Centroid: 11498.38 Hz, Bandwidth: 11216.68 Hz
# [DETECTED] 1375.00s → Centroid: 11927.01 Hz, Bandwidth: 11451.17 Hz
# [DETECTED] 1378.50s → Centroid: 11770.65 Hz, Bandwidth: 11548.38 Hz
# [DETECTED] 1381.00s → Centroid: 11766.44 Hz, Bandwidth: 11334.83 Hz
# [DETECTED] 1381.50s → Centroid: 11630.52 Hz, Bandwidth: 11419.67 Hz
# [DETECTED] 1382.00s → Centroid: 11882.45 Hz, Bandwidth: 11562.94 Hz
# [DETECTED] 1382.50s → Centroid: 11979.86 Hz, Bandwidth: 11553.12 Hz
# [DETECTED] 1387.50s → Centroid: 11967.34 Hz, Bandwidth: 11365.63 Hz
# [DETECTED] 1414.50s → Centroid: 11874.81 Hz, Bandwidth: 11407.76 Hz
# [DETECTED] 1415.00s → Centroid: 11367.29 Hz, Bandwidth: 11431.72 Hz
# [DETECTED] 1415.50s → Centroid: 11991.71 Hz, Bandwidth: 11417.77 Hz
# [DETECTED] 1418.50s → Centroid: 11939.85 Hz, Bandwidth: 11195.01 Hz
# [DETECTED] 1419.00s → Centroid: 11823.86 Hz, Bandwidth: 11366.25 Hz
# [DETECTED] 1420.50s → Centroid: 11705.17 Hz, Bandwidth: 11261.44 Hz
# [DETECTED] 1421.00s → Centroid: 11140.37 Hz, Bandwidth: 11150.10 Hz
# [DETECTED] 1421.50s → Centroid: 11262.26 Hz, Bandwidth: 11174.81 Hz
# [DETECTED] 1422.00s → Centroid: 11339.47 Hz, Bandwidth: 11335.21 Hz
# [DETECTED] 1422.50s → Centroid: 10365.36 Hz, Bandwidth: 11055.08 Hz
# [DETECTED] 1423.50s → Centroid: 11412.38 Hz, Bandwidth: 11052.01 Hz
# [DETECTED] 1428.00s → Centroid: 11400.13 Hz, Bandwidth: 11175.00 Hz
# [DETECTED] 1429.50s → Centroid: 11214.39 Hz, Bandwidth: 11126.18 Hz
# [DETECTED] 1430.00s → Centroid: 10604.01 Hz, Bandwidth: 11181.01 Hz
# [DETECTED] 1430.50s → Centroid: 11762.34 Hz, Bandwidth: 11625.14 Hz
# [DETECTED] 1431.00s → Centroid: 11362.17 Hz, Bandwidth: 11494.98 Hz
# [DETECTED] 1447.50s → Centroid: 10201.44 Hz, Bandwidth: 11111.84 Hz
# [DETECTED] 1448.00s → Centroid: 11052.14 Hz, Bandwidth: 11470.64 Hz
# [DETECTED] 1448.50s → Centroid: 10364.66 Hz, Bandwidth: 11598.35 Hz
# [DETECTED] 1449.00s → Centroid: 10551.02 Hz, Bandwidth: 11674.50 Hz
# [DETECTED] 1449.50s → Centroid: 11233.96 Hz, Bandwidth: 11728.07 Hz
# [DETECTED] 1451.00s → Centroid: 11951.84 Hz, Bandwidth: 12104.75 Hz
# [DETECTED] 1451.50s → Centroid: 11708.65 Hz, Bandwidth: 11896.17 Hz
# [DETECTED] 1454.50s → Centroid: 11970.71 Hz, Bandwidth: 11797.45 Hz
# [DETECTED] 1455.00s → Centroid: 11342.41 Hz, Bandwidth: 11750.12 Hz
# [DETECTED] 1455.50s → Centroid: 11307.32 Hz, Bandwidth: 12092.37 Hz
# [DETECTED] 1537.50s → Centroid: 9430.35 Hz, Bandwidth: 11529.14 Hz
# [DETECTED] 1541.50s → Centroid: 9259.53 Hz, Bandwidth: 11876.17 Hz
# [DETECTED] 1542.00s → Centroid: 9547.67 Hz, Bandwidth: 12325.10 Hz
# [DETECTED] 1546.50s → Centroid: 10696.90 Hz, Bandwidth: 12313.32 Hz
# [DETECTED] 1547.50s → Centroid: 9570.00 Hz, Bandwidth: 11392.86 Hz
# [DETECTED] 1548.00s → Centroid: 10677.38 Hz, Bandwidth: 12349.12 Hz
# [DETECTED] 1548.50s → Centroid: 10962.11 Hz, Bandwidth: 12348.82 Hz
# [DETECTED] 1549.00s → Centroid: 11000.23 Hz, Bandwidth: 12297.13 Hz
# [DETECTED] 1549.50s → Centroid: 10764.69 Hz, Bandwidth: 12187.84 Hz
# [DETECTED] 1550.00s → Centroid: 10250.50 Hz, Bandwidth: 11752.24 Hz
# [DETECTED] 1550.50s → Centroid: 9833.19 Hz, Bandwidth: 11422.29 Hz
# [DETECTED] 1551.50s → Centroid: 9075.92 Hz, Bandwidth: 11275.40 Hz
# [DETECTED] 1552.00s → Centroid: 9492.31 Hz, Bandwidth: 11688.18 Hz
# [DETECTED] 1552.50s → Centroid: 9399.49 Hz, Bandwidth: 11401.22 Hz
# [DETECTED] 1561.50s → Centroid: 9999.42 Hz, Bandwidth: 11093.12 Hz
# [DETECTED] 1562.00s → Centroid: 9646.58 Hz, Bandwidth: 11177.79 Hz
# [DETECTED] 1562.50s → Centroid: 9700.62 Hz, Bandwidth: 11099.62 Hz
# [DETECTED] 1563.00s → Centroid: 9764.29 Hz, Bandwidth: 11140.91 Hz
# [DETECTED] 1563.50s → Centroid: 9370.69 Hz, Bandwidth: 11192.73 Hz
# [DETECTED] 1564.00s → Centroid: 9546.46 Hz, Bandwidth: 11406.27 Hz
# [DETECTED] 1564.50s → Centroid: 9587.69 Hz, Bandwidth: 11414.99 Hz
# [DETECTED] 1565.00s → Centroid: 9628.88 Hz, Bandwidth: 11426.02 Hz
# [DETECTED] 1565.50s → Centroid: 10047.50 Hz, Bandwidth: 11503.55 Hz
# [DETECTED] 1566.00s → Centroid: 10592.86 Hz, Bandwidth: 11714.38 Hz
# [DETECTED] 1566.50s → Centroid: 10672.22 Hz, Bandwidth: 11791.27 Hz
# [DETECTED] 1567.00s → Centroid: 9846.07 Hz, Bandwidth: 11399.11 Hz
# [DETECTED] 1567.50s → Centroid: 10278.55 Hz, Bandwidth: 11317.80 Hz
# [DETECTED] 1568.00s → Centroid: 10415.88 Hz, Bandwidth: 11514.90 Hz
# [DETECTED] 1568.50s → Centroid: 10286.95 Hz, Bandwidth: 11519.34 Hz
# [DETECTED] 1569.00s → Centroid: 10059.70 Hz, Bandwidth: 11303.69 Hz
# [DETECTED] 1569.50s → Centroid: 9977.94 Hz, Bandwidth: 11176.49 Hz
# [DETECTED] 1570.00s → Centroid: 10257.88 Hz, Bandwidth: 11278.45 Hz
# [DETECTED] 1570.50s → Centroid: 10071.19 Hz, Bandwidth: 11206.79 Hz
# [DETECTED] 1571.00s → Centroid: 10995.39 Hz, Bandwidth: 11174.30 Hz
# [DETECTED] 1571.50s → Centroid: 11333.32 Hz, Bandwidth: 11225.46 Hz
# [DETECTED] 1572.00s → Centroid: 11487.47 Hz, Bandwidth: 11252.39 Hz
# [DETECTED] 1572.50s → Centroid: 10495.12 Hz, Bandwidth: 11122.94 Hz
# [DETECTED] 1573.00s → Centroid: 10431.17 Hz, Bandwidth: 11029.81 Hz
# [DETECTED] 1573.50s → Centroid: 11622.41 Hz, Bandwidth: 11296.15 Hz
# [DETECTED] 1632.50s → Centroid: 11967.23 Hz, Bandwidth: 11911.23 Hz
# [DETECTED] 1638.00s → Centroid: 11882.70 Hz, Bandwidth: 11498.92 Hz
# [DETECTED] 1638.50s → Centroid: 9840.90 Hz, Bandwidth: 11406.27 Hz
# [DETECTED] 1639.50s → Centroid: 9495.48 Hz, Bandwidth: 11210.38 Hz
# [DETECTED] 1640.00s → Centroid: 9861.29 Hz, Bandwidth: 11341.78 Hz
# [DETECTED] 1640.50s → Centroid: 9414.84 Hz, Bandwidth: 11418.58 Hz
# [DETECTED] 1645.50s → Centroid: 9222.14 Hz, Bandwidth: 11719.61 Hz
# [DETECTED] 1646.00s → Centroid: 9039.66 Hz, Bandwidth: 11629.27 Hz
# [DETECTED] 1646.50s → Centroid: 9058.16 Hz, Bandwidth: 11828.36 Hz
# [DETECTED] 1647.00s → Centroid: 9551.19 Hz, Bandwidth: 12260.58 Hz
# [DETECTED] 1651.50s → Centroid: 9186.69 Hz, Bandwidth: 12432.60 Hz
# [DETECTED] 1653.00s → Centroid: 10505.46 Hz, Bandwidth: 12250.08 Hz
# [DETECTED] 1655.50s → Centroid: 9177.62 Hz, Bandwidth: 12220.44 Hz
# [DETECTED] 1662.00s → Centroid: 9596.07 Hz, Bandwidth: 11406.89 Hz
# [DETECTED] 1663.50s → Centroid: 10445.89 Hz, Bandwidth: 11662.81 Hz
# [DETECTED] 1665.50s → Centroid: 11702.38 Hz, Bandwidth: 11657.89 Hz
# [DETECTED] 1666.00s → Centroid: 11970.87 Hz, Bandwidth: 11888.13 Hz
# [DETECTED] 1666.50s → Centroid: 11371.43 Hz, Bandwidth: 11847.70 Hz
# [DETECTED] 1667.00s → Centroid: 10807.51 Hz, Bandwidth: 11612.53 Hz
# [DETECTED] 1667.50s → Centroid: 11236.32 Hz, Bandwidth: 11669.16 Hz
# [DETECTED] 1668.00s → Centroid: 11585.98 Hz, Bandwidth: 12006.55 Hz
# [DETECTED] 1671.00s → Centroid: 11643.49 Hz, Bandwidth: 11485.84 Hz
# [DETECTED] 1671.50s → Centroid: 9999.68 Hz, Bandwidth: 11459.58 Hz
# [DETECTED] 1672.50s → Centroid: 11403.19 Hz, Bandwidth: 11779.52 Hz
# [DETECTED] 1673.50s → Centroid: 10609.17 Hz, Bandwidth: 11894.94 Hz
# [DETECTED] 1674.00s → Centroid: 11229.17 Hz, Bandwidth: 12319.58 Hz
# [DETECTED] 1674.50s → Centroid: 11588.05 Hz, Bandwidth: 12313.92 Hz
# [DETECTED] 1679.50s → Centroid: 11394.09 Hz, Bandwidth: 12302.19 Hz
# [DETECTED] 1680.00s → Centroid: 9942.09 Hz, Bandwidth: 11883.24 Hz
# [DETECTED] 1680.50s → Centroid: 10772.38 Hz, Bandwidth: 11984.82 Hz
# [DETECTED] 1681.50s → Centroid: 11171.78 Hz, Bandwidth: 12386.47 Hz
# [DETECTED] 1685.50s → Centroid: 9829.74 Hz, Bandwidth: 11503.12 Hz
# [DETECTED] 1686.00s → Centroid: 9780.76 Hz, Bandwidth: 11600.47 Hz
# [DETECTED] 1686.50s → Centroid: 11208.56 Hz, Bandwidth: 12219.51 Hz
# [DETECTED] 1687.00s → Centroid: 11517.86 Hz, Bandwidth: 12299.09 Hz
# [DETECTED] 1692.00s → Centroid: 11671.36 Hz, Bandwidth: 12242.91 Hz
# [DETECTED] 1692.50s → Centroid: 11969.04 Hz, Bandwidth: 12314.31 Hz
# [DETECTED] 1694.00s → Centroid: 11889.87 Hz, Bandwidth: 12247.78 Hz
# [DETECTED] 1696.00s → Centroid: 11955.67 Hz, Bandwidth: 11377.56 Hz
# [DETECTED] 1708.50s → Centroid: 11046.76 Hz, Bandwidth: 11437.42 Hz
# [DETECTED] 1709.00s → Centroid: 10903.64 Hz, Bandwidth: 11487.89 Hz
# [DETECTED] 1709.50s → Centroid: 11129.72 Hz, Bandwidth: 11448.54 Hz
# [DETECTED] 1710.00s → Centroid: 11342.27 Hz, Bandwidth: 11567.94 Hz
# [DETECTED] 1710.50s → Centroid: 11154.66 Hz, Bandwidth: 11761.16 Hz
# [DETECTED] 1711.00s → Centroid: 10903.56 Hz, Bandwidth: 11598.69 Hz
# [DETECTED] 1711.50s → Centroid: 10815.60 Hz, Bandwidth: 11457.35 Hz
# [DETECTED] 1712.00s → Centroid: 10654.49 Hz, Bandwidth: 11286.82 Hz
# [DETECTED] 1712.50s → Centroid: 10415.63 Hz, Bandwidth: 11259.90 Hz
# [DETECTED] 1713.00s → Centroid: 9672.82 Hz, Bandwidth: 11259.07 Hz
# [DETECTED] 1713.50s → Centroid: 9502.06 Hz, Bandwidth: 11220.64 Hz
# [DETECTED] 1714.00s → Centroid: 10068.78 Hz, Bandwidth: 11125.31 Hz
# [DETECTED] 1715.50s → Centroid: 9718.30 Hz, Bandwidth: 11044.10 Hz
# [DETECTED] 1716.00s → Centroid: 10084.70 Hz, Bandwidth: 11162.54 Hz
# [DETECTED] 1716.50s → Centroid: 9594.49 Hz, Bandwidth: 11071.42 Hz
# [DETECTED] 1719.50s → Centroid: 9274.78 Hz, Bandwidth: 11052.77 Hz
# [DETECTED] 1720.00s → Centroid: 9457.88 Hz, Bandwidth: 11085.44 Hz
# [DETECTED] 1720.50s → Centroid: 9541.13 Hz, Bandwidth: 11079.16 Hz
# [DETECTED] 1721.00s → Centroid: 9320.31 Hz, Bandwidth: 11071.42 Hz
# [DETECTED] 1721.50s → Centroid: 9426.30 Hz, Bandwidth: 11052.22 Hz
# [DETECTED] 1724.50s → Centroid: 9418.82 Hz, Bandwidth: 11180.51 Hz
# [DETECTED] 1725.00s → Centroid: 9781.05 Hz, Bandwidth: 11364.32 Hz
# [DETECTED] 1726.00s → Centroid: 9034.24 Hz, Bandwidth: 11416.32 Hz
# [DETECTED] 1726.50s → Centroid: 9196.64 Hz, Bandwidth: 11569.20 Hz
# [DETECTED] 1727.00s → Centroid: 9263.99 Hz, Bandwidth: 11736.66 Hz
# [DETECTED] 1728.50s → Centroid: 9848.83 Hz, Bandwidth: 11961.34 Hz
# [DETECTED] 1729.00s → Centroid: 10939.46 Hz, Bandwidth: 11937.07 Hz
# [DETECTED] 1729.50s → Centroid: 10932.61 Hz, Bandwidth: 11686.81 Hz
# [DETECTED] 1730.00s → Centroid: 10373.77 Hz, Bandwidth: 11572.51 Hz
# [DETECTED] 1730.50s → Centroid: 10585.92 Hz, Bandwidth: 11591.37 Hz
# [DETECTED] 1731.00s → Centroid: 11334.12 Hz, Bandwidth: 11657.91 Hz
# [DETECTED] 1731.50s → Centroid: 11922.71 Hz, Bandwidth: 11646.57 Hz
# [DETECTED] 1732.50s → Centroid: 11987.22 Hz, Bandwidth: 11836.96 Hz
# [DETECTED] 1734.50s → Centroid: 11959.95 Hz, Bandwidth: 11997.49 Hz
# [DETECTED] 1740.00s → Centroid: 11339.47 Hz, Bandwidth: 11950.96 Hz
# [DETECTED] 1741.50s → Centroid: 11294.41 Hz, Bandwidth: 12308.65 Hz
# [DETECTED] 1743.00s → Centroid: 10968.22 Hz, Bandwidth: 12414.23 Hz
# [DETECTED] 1743.50s → Centroid: 9754.02 Hz, Bandwidth: 11673.81 Hz
# [DETECTED] 1744.00s → Centroid: 9248.64 Hz, Bandwidth: 11378.93 Hz
# [DETECTED] 1744.50s → Centroid: 9967.14 Hz, Bandwidth: 12164.45 Hz
# [DETECTED] 1746.50s → Centroid: 11061.06 Hz, Bandwidth: 12471.29 Hz
# [DETECTED] 1751.00s → Centroid: 11270.79 Hz, Bandwidth: 12229.44 Hz
# [DETECTED] 1751.50s → Centroid: 11164.08 Hz, Bandwidth: 12069.36 Hz
# [DETECTED] 1752.00s → Centroid: 11477.47 Hz, Bandwidth: 12224.38 Hz
# [DETECTED] 1753.00s → Centroid: 11725.40 Hz, Bandwidth: 12208.02 Hz
# [DETECTED] 1753.50s → Centroid: 11345.29 Hz, Bandwidth: 12173.90 Hz
# [DETECTED] 1754.00s → Centroid: 11751.15 Hz, Bandwidth: 12419.60 Hz
# [DETECTED] 1757.00s → Centroid: 11916.52 Hz, Bandwidth: 12283.72 Hz
# [DETECTED] 1758.00s → Centroid: 11787.74 Hz, Bandwidth: 12302.37 Hz
# [DETECTED] 1833.50s → Centroid: 11908.09 Hz, Bandwidth: 11584.26 Hz
# [DETECTED] 1834.00s → Centroid: 11728.06 Hz, Bandwidth: 11793.96 Hz
# [DETECTED] 1958.00s → Centroid: 9940.27 Hz, Bandwidth: 12195.29 Hz
# [DETECTED] 1987.00s → Centroid: 11946.59 Hz, Bandwidth: 12226.72 Hz
# [DETECTED] 2001.50s → Centroid: 11615.40 Hz, Bandwidth: 11624.51 Hz
# [DETECTED] 2003.00s → Centroid: 11507.31 Hz, Bandwidth: 11846.37 Hz
# [DETECTED] 2004.50s → Centroid: 11369.48 Hz, Bandwidth: 11755.40 Hz
# [DETECTED] 2006.00s → Centroid: 11704.30 Hz, Bandwidth: 12306.91 Hz
# [DETECTED] 2006.50s → Centroid: 11608.44 Hz, Bandwidth: 12323.01 Hz
# [DETECTED] 2007.50s → Centroid: 11923.39 Hz, Bandwidth: 12114.13 Hz
# [DETECTED] 2008.00s → Centroid: 11666.46 Hz, Bandwidth: 12250.64 Hz
# [DETECTED] 2024.00s → Centroid: 10386.96 Hz, Bandwidth: 12419.03 Hz
# [DETECTED] 2025.50s → Centroid: 9539.19 Hz, Bandwidth: 12307.59 Hz
# [DETECTED] 2026.00s → Centroid: 10185.60 Hz, Bandwidth: 12402.17 Hz
# [DETECTED] 2042.50s → Centroid: 9470.92 Hz, Bandwidth: 12360.14 Hz
# [DETECTED] 2043.00s → Centroid: 9569.59 Hz, Bandwidth: 12304.08 Hz
# [DETECTED] 2043.50s → Centroid: 11210.69 Hz, Bandwidth: 12244.41 Hz
# [DETECTED] 2044.00s → Centroid: 10764.33 Hz, Bandwidth: 11790.11 Hz
# [DETECTED] 2044.50s → Centroid: 10555.16 Hz, Bandwidth: 11977.54 Hz
# [DETECTED] 2045.00s → Centroid: 10136.86 Hz, Bandwidth: 12264.80 Hz
# [DETECTED] 2045.50s → Centroid: 9876.18 Hz, Bandwidth: 12016.28 Hz
# [DETECTED] 2046.00s → Centroid: 10165.18 Hz, Bandwidth: 11824.24 Hz
# [DETECTED] 2046.50s → Centroid: 10860.17 Hz, Bandwidth: 12060.62 Hz
# [DETECTED] 2047.00s → Centroid: 11714.49 Hz, Bandwidth: 11997.27 Hz
# [DETECTED] 2047.50s → Centroid: 10518.48 Hz, Bandwidth: 11674.39 Hz
# [DETECTED] 2048.00s → Centroid: 10805.42 Hz, Bandwidth: 11463.77 Hz
# [DETECTED] 2048.50s → Centroid: 10700.89 Hz, Bandwidth: 11137.21 Hz
# [DETECTED] 2049.00s → Centroid: 10159.05 Hz, Bandwidth: 11348.76 Hz
# [DETECTED] 2049.50s → Centroid: 11616.67 Hz, Bandwidth: 12300.68 Hz
# [DETECTED] 2050.50s → Centroid: 10391.12 Hz, Bandwidth: 12100.96 Hz
# [DETECTED] 2051.00s → Centroid: 11376.75 Hz, Bandwidth: 12032.88 Hz
# [DETECTED] 2051.50s → Centroid: 10416.30 Hz, Bandwidth: 12290.07 Hz
# [DETECTED] 2053.50s → Centroid: 9408.80 Hz, Bandwidth: 12349.98 Hz
# [DETECTED] 2069.00s → Centroid: 10852.22 Hz, Bandwidth: 11046.10 Hz
# [DETECTED] 2069.50s → Centroid: 11056.30 Hz, Bandwidth: 11156.45 Hz
# [DETECTED] 2070.00s → Centroid: 11177.63 Hz, Bandwidth: 11267.98 Hz
# [DETECTED] 2070.50s → Centroid: 10592.66 Hz, Bandwidth: 11409.77 Hz
# [DETECTED] 2071.00s → Centroid: 10858.91 Hz, Bandwidth: 11360.82 Hz
# [DETECTED] 2071.50s → Centroid: 10417.77 Hz, Bandwidth: 11264.76 Hz
# [DETECTED] 2072.00s → Centroid: 11072.68 Hz, Bandwidth: 11327.42 Hz
# [DETECTED] 2072.50s → Centroid: 11468.67 Hz, Bandwidth: 11578.57 Hz
# [DETECTED] 2073.00s → Centroid: 10468.58 Hz, Bandwidth: 11771.55 Hz
# [DETECTED] 2073.50s → Centroid: 10712.49 Hz, Bandwidth: 11871.35 Hz
# [DETECTED] 2074.00s → Centroid: 11196.95 Hz, Bandwidth: 11841.86 Hz
# [DETECTED] 2074.50s → Centroid: 11301.08 Hz, Bandwidth: 11876.20 Hz
# [DETECTED] 2075.00s → Centroid: 11423.60 Hz, Bandwidth: 11854.29 Hz
# [DETECTED] 2075.50s → Centroid: 10952.11 Hz, Bandwidth: 11781.00 Hz
# [DETECTED] 2076.00s → Centroid: 11364.89 Hz, Bandwidth: 11796.31 Hz
# [DETECTED] 2076.50s → Centroid: 11421.71 Hz, Bandwidth: 11730.53 Hz
# [DETECTED] 2077.00s → Centroid: 11085.54 Hz, Bandwidth: 11752.01 Hz
# [DETECTED] 2077.50s → Centroid: 11534.04 Hz, Bandwidth: 11627.02 Hz
# [DETECTED] 2078.50s → Centroid: 11886.04 Hz, Bandwidth: 11506.99 Hz
# [DETECTED] 2079.00s → Centroid: 11866.83 Hz, Bandwidth: 11479.39 Hz
# [DETECTED] 2080.00s → Centroid: 11832.91 Hz, Bandwidth: 11512.75 Hz
# [DETECTED] 2081.00s → Centroid: 11863.33 Hz, Bandwidth: 11349.76 Hz
# [DETECTED] 2081.50s → Centroid: 11888.83 Hz, Bandwidth: 11389.00 Hz
# [DETECTED] 2082.50s → Centroid: 11545.88 Hz, Bandwidth: 11697.20 Hz
# [DETECTED] 2083.00s → Centroid: 11826.93 Hz, Bandwidth: 11540.58 Hz
# [DETECTED] 2084.50s → Centroid: 11459.47 Hz, Bandwidth: 11911.16 Hz
# [DETECTED] 2086.00s → Centroid: 11628.74 Hz, Bandwidth: 11609.07 Hz
# [DETECTED] 2086.50s → Centroid: 11299.38 Hz, Bandwidth: 11476.81 Hz
# [DETECTED] 2087.00s → Centroid: 11618.40 Hz, Bandwidth: 11490.35 Hz
# [DETECTED] 2091.50s → Centroid: 10852.82 Hz, Bandwidth: 12442.92 Hz
# [DETECTED] 2092.00s → Centroid: 10605.24 Hz, Bandwidth: 12189.85 Hz
# [DETECTED] 2092.50s → Centroid: 10782.25 Hz, Bandwidth: 12247.40 Hz
# [DETECTED] 2093.50s → Centroid: 10905.77 Hz, Bandwidth: 11998.37 Hz
# [DETECTED] 2094.00s → Centroid: 9557.86 Hz, Bandwidth: 11912.28 Hz
# [DETECTED] 2094.50s → Centroid: 11458.48 Hz, Bandwidth: 12232.72 Hz
# [DETECTED] 2095.00s → Centroid: 10845.43 Hz, Bandwidth: 12185.21 Hz
# [DETECTED] 2095.50s → Centroid: 10575.31 Hz, Bandwidth: 12349.86 Hz
# [DETECTED] 2097.50s → Centroid: 10619.72 Hz, Bandwidth: 12463.73 Hz
# [DETECTED] 2099.50s → Centroid: 9998.65 Hz, Bandwidth: 12441.80 Hz
# [DETECTED] 2103.00s → Centroid: 10164.30 Hz, Bandwidth: 12480.92 Hz
# [DETECTED] 2103.50s → Centroid: 10526.42 Hz, Bandwidth: 12403.74 Hz
# [DETECTED] 2104.00s → Centroid: 10446.93 Hz, Bandwidth: 12344.08 Hz
# [DETECTED] 2104.50s → Centroid: 10298.11 Hz, Bandwidth: 12431.97 Hz
# [DETECTED] 2114.00s → Centroid: 11840.31 Hz, Bandwidth: 12423.81 Hz
# [DETECTED] 2114.50s → Centroid: 11626.72 Hz, Bandwidth: 12062.68 Hz
# [DETECTED] 2119.00s → Centroid: 10799.23 Hz, Bandwidth: 12438.67 Hz
# [DETECTED] 2132.00s → Centroid: 10816.90 Hz, Bandwidth: 12499.26 Hz
# [DETECTED] 2132.50s → Centroid: 10447.78 Hz, Bandwidth: 12453.45 Hz
# [DETECTED] 2133.00s → Centroid: 11527.50 Hz, Bandwidth: 12426.05 Hz
# [DETECTED] 2147.50s → Centroid: 9881.73 Hz, Bandwidth: 12350.11 Hz
# [DETECTED] 2150.50s → Centroid: 10897.74 Hz, Bandwidth: 12127.31 Hz
# [DETECTED] 2151.00s → Centroid: 11459.89 Hz, Bandwidth: 12005.81 Hz
# [DETECTED] 2151.50s → Centroid: 10750.46 Hz, Bandwidth: 11947.05 Hz
# [DETECTED] 2152.00s → Centroid: 10684.41 Hz, Bandwidth: 11830.07 Hz
# [DETECTED] 2152.50s → Centroid: 10334.13 Hz, Bandwidth: 11806.23 Hz
# [DETECTED] 2153.00s → Centroid: 10904.26 Hz, Bandwidth: 11777.64 Hz
# [DETECTED] 2153.50s → Centroid: 9908.15 Hz, Bandwidth: 11702.05 Hz
# [DETECTED] 2154.00s → Centroid: 9782.74 Hz, Bandwidth: 11837.57 Hz
# [DETECTED] 2155.00s → Centroid: 10996.32 Hz, Bandwidth: 11984.69 Hz
# [DETECTED] 2155.50s → Centroid: 10648.05 Hz, Bandwidth: 11756.32 Hz
# [DETECTED] 2156.50s → Centroid: 11332.98 Hz, Bandwidth: 12175.00 Hz
# [DETECTED] 2157.00s → Centroid: 11222.47 Hz, Bandwidth: 12334.77 Hz
# [DETECTED] 2158.00s → Centroid: 10676.21 Hz, Bandwidth: 12172.37 Hz
# [DETECTED] 2158.50s → Centroid: 10785.97 Hz, Bandwidth: 12284.63 Hz
# [DETECTED] 2159.50s → Centroid: 11257.33 Hz, Bandwidth: 12027.58 Hz
# [DETECTED] 2160.00s → Centroid: 9227.46 Hz, Bandwidth: 11784.95 Hz
# [DETECTED] 2160.50s → Centroid: 9962.78 Hz, Bandwidth: 12070.95 Hz
# [DETECTED] 2175.00s → Centroid: 9972.91 Hz, Bandwidth: 12350.12 Hz
# [DETECTED] 2175.50s → Centroid: 9694.15 Hz, Bandwidth: 12106.69 Hz
# [DETECTED] 2176.00s → Centroid: 9716.93 Hz, Bandwidth: 12190.04 Hz
# [DETECTED] 2181.00s → Centroid: 9553.92 Hz, Bandwidth: 12275.27 Hz
# [DETECTED] 2182.00s → Centroid: 9121.97 Hz, Bandwidth: 11963.57 Hz
# [DETECTED] 2182.50s → Centroid: 9344.26 Hz, Bandwidth: 12375.07 Hz
# [DETECTED] 2184.50s → Centroid: 9731.57 Hz, Bandwidth: 12433.84 Hz
# [DETECTED] 2185.50s → Centroid: 9771.89 Hz, Bandwidth: 12382.05 Hz
# [DETECTED] 2186.00s → Centroid: 9859.59 Hz, Bandwidth: 12407.70 Hz
# [DETECTED] 2189.50s → Centroid: 10094.35 Hz, Bandwidth: 12350.83 Hz
# [DETECTED] 2191.00s → Centroid: 9746.15 Hz, Bandwidth: 12311.35 Hz
# [DETECTED] 2191.50s → Centroid: 10035.48 Hz, Bandwidth: 12339.29 Hz
# [DETECTED] 2192.00s → Centroid: 10921.83 Hz, Bandwidth: 12481.35 Hz
# [DETECTED] 2192.50s → Centroid: 9837.12 Hz, Bandwidth: 12289.30 Hz
# [DETECTED] 2193.00s → Centroid: 9383.80 Hz, Bandwidth: 12233.51 Hz
# [DETECTED] 2193.50s → Centroid: 9884.30 Hz, Bandwidth: 12171.34 Hz
# [DETECTED] 2194.00s → Centroid: 10397.10 Hz, Bandwidth: 12246.59 Hz
# [DETECTED] 2194.50s → Centroid: 9739.66 Hz, Bandwidth: 12236.64 Hz
# [DETECTED] 2195.00s → Centroid: 9920.95 Hz, Bandwidth: 12113.81 Hz
# [DETECTED] 2195.50s → Centroid: 10698.51 Hz, Bandwidth: 12224.40 Hz
# [DETECTED] 2196.00s → Centroid: 9635.09 Hz, Bandwidth: 11924.49 Hz
# [DETECTED] 2196.50s → Centroid: 9650.99 Hz, Bandwidth: 11915.40 Hz
# [DETECTED] 2197.00s → Centroid: 9570.60 Hz, Bandwidth: 12056.90 Hz
# [DETECTED] 2197.50s → Centroid: 10558.91 Hz, Bandwidth: 12192.39 Hz
# [DETECTED] 2198.00s → Centroid: 10530.46 Hz, Bandwidth: 12161.54 Hz
# [DETECTED] 2198.50s → Centroid: 9630.26 Hz, Bandwidth: 12132.94 Hz
# [DETECTED] 2199.00s → Centroid: 10781.07 Hz, Bandwidth: 12434.19 Hz
# [DETECTED] 2199.50s → Centroid: 10359.00 Hz, Bandwidth: 12192.47 Hz
# [DETECTED] 2200.00s → Centroid: 9294.46 Hz, Bandwidth: 11955.22 Hz
# [DETECTED] 2200.50s → Centroid: 9718.22 Hz, Bandwidth: 12052.83 Hz
# [DETECTED] 2201.00s → Centroid: 10580.50 Hz, Bandwidth: 12333.60 Hz
# [DETECTED] 2201.50s → Centroid: 9585.56 Hz, Bandwidth: 12211.95 Hz
# [DETECTED] 2202.00s → Centroid: 10428.97 Hz, Bandwidth: 12223.65 Hz
# [DETECTED] 2202.50s → Centroid: 10867.07 Hz, Bandwidth: 12339.48 Hz
# [DETECTED] 2203.00s → Centroid: 9727.36 Hz, Bandwidth: 12247.49 Hz
# [DETECTED] 2204.00s → Centroid: 10693.74 Hz, Bandwidth: 12366.75 Hz
# [DETECTED] 2204.50s → Centroid: 10454.71 Hz, Bandwidth: 12184.25 Hz
# [DETECTED] 2205.00s → Centroid: 9725.02 Hz, Bandwidth: 12129.70 Hz
# [DETECTED] 2205.50s → Centroid: 9328.53 Hz, Bandwidth: 12028.24 Hz
# [DETECTED] 2206.00s → Centroid: 10725.77 Hz, Bandwidth: 12144.57 Hz
# [DETECTED] 2206.50s → Centroid: 9823.78 Hz, Bandwidth: 11809.48 Hz
# [DETECTED] 2207.50s → Centroid: 10425.36 Hz, Bandwidth: 12357.37 Hz
# [DETECTED] 2208.00s → Centroid: 9249.52 Hz, Bandwidth: 12201.87 Hz
# [DETECTED] 2208.50s → Centroid: 9903.27 Hz, Bandwidth: 12327.46 Hz
# [DETECTED] 2259.50s → Centroid: 9286.97 Hz, Bandwidth: 12244.00 Hz
# [DETECTED] 2260.50s → Centroid: 9218.47 Hz, Bandwidth: 12071.23 Hz
# [DETECTED] 2265.50s → Centroid: 9175.90 Hz, Bandwidth: 12280.15 Hz
# [DETECTED] 2266.00s → Centroid: 9315.02 Hz, Bandwidth: 12225.17 Hz
# [DETECTED] 2268.00s → Centroid: 9674.69 Hz, Bandwidth: 12462.30 Hz
# [DETECTED] 2269.50s → Centroid: 10226.60 Hz, Bandwidth: 12487.93 Hz
# [DETECTED] 2270.00s → Centroid: 9758.13 Hz, Bandwidth: 12343.01 Hz
# [DETECTED] 2282.50s → Centroid: 10277.55 Hz, Bandwidth: 11880.83 Hz
# [DETECTED] 2283.00s → Centroid: 10688.58 Hz, Bandwidth: 12298.92 Hz
# [DETECTED] 2289.50s → Centroid: 11293.84 Hz, Bandwidth: 12498.17 Hz
# [DETECTED] 2290.00s → Centroid: 11513.34 Hz, Bandwidth: 12365.77 Hz
# [DETECTED] 2290.50s → Centroid: 11737.75 Hz, Bandwidth: 12459.58 Hz
# [DETECTED] 2291.00s → Centroid: 11375.14 Hz, Bandwidth: 12485.51 Hz
# [DETECTED] 2291.50s → Centroid: 11114.60 Hz, Bandwidth: 12380.05 Hz
# [DETECTED] 2292.00s → Centroid: 10719.50 Hz, Bandwidth: 12431.54 Hz
# [DETECTED] 2302.00s → Centroid: 11713.06 Hz, Bandwidth: 12415.24 Hz
# [DETECTED] 2304.50s → Centroid: 11812.23 Hz, Bandwidth: 12228.93 Hz
# [DETECTED] 2305.00s → Centroid: 11843.67 Hz, Bandwidth: 12127.33 Hz
# [DETECTED] 2305.50s → Centroid: 11775.50 Hz, Bandwidth: 12106.48 Hz
# [DETECTED] 2307.00s → Centroid: 11423.70 Hz, Bandwidth: 12053.09 Hz
# [DETECTED] 2307.50s → Centroid: 11845.59 Hz, Bandwidth: 12015.24 Hz
# [DETECTED] 2308.50s → Centroid: 11256.05 Hz, Bandwidth: 11930.73 Hz
# [DETECTED] 2309.00s → Centroid: 11556.20 Hz, Bandwidth: 11879.01 Hz
# [DETECTED] 2309.50s → Centroid: 11257.53 Hz, Bandwidth: 11887.01 Hz
# [DETECTED] 2310.00s → Centroid: 11628.80 Hz, Bandwidth: 11771.47 Hz
# [DETECTED] 2310.50s → Centroid: 11692.61 Hz, Bandwidth: 11587.64 Hz
# [DETECTED] 2311.00s → Centroid: 10650.67 Hz, Bandwidth: 11603.36 Hz
# [DETECTED] 2311.50s → Centroid: 10931.48 Hz, Bandwidth: 11706.86 Hz
# [DETECTED] 2312.00s → Centroid: 10921.12 Hz, Bandwidth: 11735.93 Hz
# [DETECTED] 2312.50s → Centroid: 10088.98 Hz, Bandwidth: 11702.02 Hz
# [DETECTED] 2313.00s → Centroid: 10705.74 Hz, Bandwidth: 11694.76 Hz
# [DETECTED] 2313.50s → Centroid: 10827.87 Hz, Bandwidth: 11577.26 Hz
# [DETECTED] 2314.00s → Centroid: 10258.63 Hz, Bandwidth: 11407.03 Hz
# [DETECTED] 2314.50s → Centroid: 10680.27 Hz, Bandwidth: 11516.54 Hz
# [DETECTED] 2315.00s → Centroid: 10324.15 Hz, Bandwidth: 11598.12 Hz
# [DETECTED] 2315.50s → Centroid: 10878.69 Hz, Bandwidth: 11573.32 Hz
# [DETECTED] 2316.00s → Centroid: 11122.07 Hz, Bandwidth: 11536.13 Hz
# [DETECTED] 2316.50s → Centroid: 10254.81 Hz, Bandwidth: 11423.81 Hz
# [DETECTED] 2317.00s → Centroid: 10382.58 Hz, Bandwidth: 11394.81 Hz
# [DETECTED] 2317.50s → Centroid: 10800.15 Hz, Bandwidth: 11405.38 Hz
# [DETECTED] 2318.00s → Centroid: 10715.54 Hz, Bandwidth: 11375.06 Hz
# [DETECTED] 2318.50s → Centroid: 10481.01 Hz, Bandwidth: 11380.55 Hz
# [DETECTED] 2319.00s → Centroid: 10169.66 Hz, Bandwidth: 11287.63 Hz
# [DETECTED] 2319.50s → Centroid: 9660.64 Hz, Bandwidth: 11193.49 Hz
# [DETECTED] 2320.00s → Centroid: 9812.62 Hz, Bandwidth: 11241.57 Hz
# [DETECTED] 2320.50s → Centroid: 9885.95 Hz, Bandwidth: 11195.78 Hz
# [DETECTED] 2321.00s → Centroid: 9306.20 Hz, Bandwidth: 11094.23 Hz
# [DETECTED] 2321.50s → Centroid: 9124.21 Hz, Bandwidth: 11080.22 Hz
# [DETECTED] 2322.00s → Centroid: 9255.83 Hz, Bandwidth: 11051.77 Hz
# [DETECTED] 2322.50s → Centroid: 9383.61 Hz, Bandwidth: 11117.58 Hz
# [DETECTED] 2323.00s → Centroid: 9169.53 Hz, Bandwidth: 11126.21 Hz
# [DETECTED] 2323.50s → Centroid: 9403.48 Hz, Bandwidth: 11215.74 Hz
# [DETECTED] 2324.00s → Centroid: 9538.62 Hz, Bandwidth: 11322.68 Hz
# [DETECTED] 2324.50s → Centroid: 9123.71 Hz, Bandwidth: 11451.84 Hz
# [DETECTED] 2333.00s → Centroid: 9190.01 Hz, Bandwidth: 11354.90 Hz
# [DETECTED] 2333.50s → Centroid: 9695.14 Hz, Bandwidth: 11556.53 Hz
# [DETECTED] 2334.00s → Centroid: 9829.07 Hz, Bandwidth: 11510.79 Hz
# [DETECTED] 2334.50s → Centroid: 9915.39 Hz, Bandwidth: 11655.09 Hz
# [DETECTED] 2335.00s → Centroid: 9284.89 Hz, Bandwidth: 11597.82 Hz
# [DETECTED] 2335.50s → Centroid: 9229.48 Hz, Bandwidth: 11504.00 Hz
# [DETECTED] 2336.00s → Centroid: 9710.51 Hz, Bandwidth: 11680.73 Hz
# [DETECTED] 2336.50s → Centroid: 9521.51 Hz, Bandwidth: 11761.49 Hz
# [DETECTED] 2337.50s → Centroid: 9023.62 Hz, Bandwidth: 11615.76 Hz
# [DETECTED] 2338.00s → Centroid: 9057.64 Hz, Bandwidth: 11496.73 Hz
# [DETECTED] 2338.50s → Centroid: 9087.00 Hz, Bandwidth: 11412.02 Hz
# [DETECTED] 2339.00s → Centroid: 9345.08 Hz, Bandwidth: 11468.77 Hz
# [DETECTED] 2339.50s → Centroid: 9584.30 Hz, Bandwidth: 11447.73 Hz
# [DETECTED] 2340.00s → Centroid: 9624.93 Hz, Bandwidth: 11489.19 Hz
# [DETECTED] 2340.50s → Centroid: 9688.18 Hz, Bandwidth: 11665.53 Hz
# [DETECTED] 2341.00s → Centroid: 10005.24 Hz, Bandwidth: 11700.09 Hz
# [DETECTED] 2341.50s → Centroid: 9995.48 Hz, Bandwidth: 11527.56 Hz
# [DETECTED] 2342.00s → Centroid: 9757.36 Hz, Bandwidth: 11434.17 Hz
# [DETECTED] 2342.50s → Centroid: 9515.15 Hz, Bandwidth: 11540.46 Hz
# [DETECTED] 2343.00s → Centroid: 9920.43 Hz, Bandwidth: 11801.97 Hz
# [DETECTED] 2343.50s → Centroid: 9889.64 Hz, Bandwidth: 11787.96 Hz
# [DETECTED] 2344.00s → Centroid: 9542.08 Hz, Bandwidth: 11582.48 Hz
# [DETECTED] 2344.50s → Centroid: 9789.74 Hz, Bandwidth: 11598.95 Hz
# [DETECTED] 2345.00s → Centroid: 9786.68 Hz, Bandwidth: 11743.84 Hz
# [DETECTED] 2345.50s → Centroid: 9851.45 Hz, Bandwidth: 11856.88 Hz
# [DETECTED] 2346.00s → Centroid: 9944.70 Hz, Bandwidth: 11885.65 Hz
# [DETECTED] 2346.50s → Centroid: 9844.21 Hz, Bandwidth: 11885.60 Hz
# [DETECTED] 2347.00s → Centroid: 10341.24 Hz, Bandwidth: 11986.01 Hz
# [DETECTED] 2347.50s → Centroid: 10608.84 Hz, Bandwidth: 12004.84 Hz
# [DETECTED] 2348.00s → Centroid: 10292.80 Hz, Bandwidth: 11888.20 Hz
# [DETECTED] 2348.50s → Centroid: 9862.45 Hz, Bandwidth: 11801.98 Hz
# [DETECTED] 2349.00s → Centroid: 9874.46 Hz, Bandwidth: 11840.87 Hz
# [DETECTED] 2349.50s → Centroid: 10243.36 Hz, Bandwidth: 11922.22 Hz
# [DETECTED] 2350.00s → Centroid: 10297.71 Hz, Bandwidth: 11996.79 Hz
# [DETECTED] 2350.50s → Centroid: 10117.71 Hz, Bandwidth: 12043.24 Hz
# [DETECTED] 2351.00s → Centroid: 9590.23 Hz, Bandwidth: 11915.63 Hz
# [DETECTED] 2351.50s → Centroid: 9344.82 Hz, Bandwidth: 11847.03 Hz
# [DETECTED] 2352.00s → Centroid: 9166.39 Hz, Bandwidth: 11805.12 Hz
# [DETECTED] 2352.50s → Centroid: 9246.18 Hz, Bandwidth: 11845.64 Hz
# [DETECTED] 2353.00s → Centroid: 9917.12 Hz, Bandwidth: 12031.99 Hz
# [DETECTED] 2353.50s → Centroid: 10694.33 Hz, Bandwidth: 12289.55 Hz
# [DETECTED] 2355.00s → Centroid: 11486.09 Hz, Bandwidth: 12472.96 Hz
# [DETECTED] 2355.50s → Centroid: 11328.02 Hz, Bandwidth: 12404.64 Hz
# [DETECTED] 2356.00s → Centroid: 11650.91 Hz, Bandwidth: 12482.37 Hz
# [DETECTED] 2364.50s → Centroid: 11934.51 Hz, Bandwidth: 12487.24 Hz
# [DETECTED] 2368.00s → Centroid: 11652.29 Hz, Bandwidth: 12314.17 Hz
# [DETECTED] 2368.50s → Centroid: 11700.51 Hz, Bandwidth: 12236.41 Hz
# [DETECTED] 2373.50s → Centroid: 11945.00 Hz, Bandwidth: 12446.32 Hz
# [DETECTED] 2377.50s → Centroid: 11806.12 Hz, Bandwidth: 12465.52 Hz
# [DETECTED] 2415.50s → Centroid: 11578.69 Hz, Bandwidth: 11185.21 Hz
# [DETECTED] 2416.00s → Centroid: 11199.57 Hz, Bandwidth: 11087.27 Hz
# [DETECTED] 2416.50s → Centroid: 11407.63 Hz, Bandwidth: 11198.83 Hz
# [DETECTED] 2417.00s → Centroid: 11678.59 Hz, Bandwidth: 11319.84 Hz
# [DETECTED] 2417.50s → Centroid: 11952.37 Hz, Bandwidth: 11426.36 Hz
# [DETECTED] 2418.00s → Centroid: 11693.44 Hz, Bandwidth: 11342.05 Hz
# [DETECTED] 2418.50s → Centroid: 11368.20 Hz, Bandwidth: 11351.04 Hz
# [DETECTED] 2419.00s → Centroid: 11406.97 Hz, Bandwidth: 11579.94 Hz
# [DETECTED] 2419.50s → Centroid: 11381.64 Hz, Bandwidth: 11530.63 Hz
# [DETECTED] 2420.00s → Centroid: 11336.69 Hz, Bandwidth: 11436.70 Hz
# [DETECTED] 2420.50s → Centroid: 11125.56 Hz, Bandwidth: 11602.16 Hz
# [DETECTED] 2421.00s → Centroid: 10728.52 Hz, Bandwidth: 11670.74 Hz
# [DETECTED] 2421.50s → Centroid: 10672.22 Hz, Bandwidth: 11558.84 Hz
# [DETECTED] 2422.00s → Centroid: 11285.51 Hz, Bandwidth: 11897.15 Hz
# [DETECTED] 2422.50s → Centroid: 11411.18 Hz, Bandwidth: 12331.14 Hz
# [DETECTED] 2423.00s → Centroid: 11243.63 Hz, Bandwidth: 12166.87 Hz
# [DETECTED] 2423.50s → Centroid: 11791.33 Hz, Bandwidth: 12052.27 Hz
# [DETECTED] 2425.50s → Centroid: 11225.15 Hz, Bandwidth: 11829.60 Hz
# [DETECTED] 2426.00s → Centroid: 11510.21 Hz, Bandwidth: 12020.44 Hz
# [DETECTED] 2426.50s → Centroid: 11845.58 Hz, Bandwidth: 12214.63 Hz
# [DETECTED] 2427.00s → Centroid: 11853.13 Hz, Bandwidth: 12202.34 Hz
# [DETECTED] 2429.00s → Centroid: 11692.00 Hz, Bandwidth: 12454.03 Hz
# [DETECTED] 2430.00s → Centroid: 11372.97 Hz, Bandwidth: 12447.02 Hz
# [DETECTED] 2430.50s → Centroid: 11180.84 Hz, Bandwidth: 12243.11 Hz
# [DETECTED] 2431.00s → Centroid: 10938.84 Hz, Bandwidth: 12212.19 Hz
# [DETECTED] 2431.50s → Centroid: 10706.82 Hz, Bandwidth: 12236.65 Hz
# [DETECTED] 2432.00s → Centroid: 10599.29 Hz, Bandwidth: 12193.73 Hz
# [DETECTED] 2432.50s → Centroid: 9947.90 Hz, Bandwidth: 11959.17 Hz
# [DETECTED] 2433.00s → Centroid: 9836.12 Hz, Bandwidth: 11944.86 Hz
# [DETECTED] 2433.50s → Centroid: 11003.33 Hz, Bandwidth: 12274.58 Hz
# [DETECTED] 2434.50s → Centroid: 10756.40 Hz, Bandwidth: 12404.92 Hz
# [DETECTED] 2435.00s → Centroid: 10698.61 Hz, Bandwidth: 12321.26 Hz
# [DETECTED] 2435.50s → Centroid: 10944.28 Hz, Bandwidth: 12414.79 Hz
# [DETECTED] 2436.00s → Centroid: 9743.59 Hz, Bandwidth: 11959.16 Hz
# [DETECTED] 2436.50s → Centroid: 9280.34 Hz, Bandwidth: 11638.43 Hz
# [DETECTED] 2437.00s → Centroid: 9918.70 Hz, Bandwidth: 11757.66 Hz
# [DETECTED] 2437.50s → Centroid: 9738.80 Hz, Bandwidth: 11581.49 Hz
# [DETECTED] 2438.00s → Centroid: 9004.22 Hz, Bandwidth: 11272.35 Hz
# [DETECTED] 2462.50s → Centroid: 9939.47 Hz, Bandwidth: 11009.16 Hz
# [DETECTED] 2463.00s → Centroid: 10072.86 Hz, Bandwidth: 11200.24 Hz
# [DETECTED] 2463.50s → Centroid: 11539.66 Hz, Bandwidth: 11377.46 Hz
# [DETECTED] 2464.00s → Centroid: 11569.52 Hz, Bandwidth: 11304.38 Hz
# [DETECTED] 2464.50s → Centroid: 10545.87 Hz, Bandwidth: 11178.14 Hz
# [DETECTED] 2465.00s → Centroid: 10087.80 Hz, Bandwidth: 11104.14 Hz
# [DETECTED] 2465.50s → Centroid: 9622.77 Hz, Bandwidth: 11277.96 Hz
# [DETECTED] 2466.00s → Centroid: 9077.99 Hz, Bandwidth: 11358.44 Hz
# [DETECTED] 2479.00s → Centroid: 9117.66 Hz, Bandwidth: 12358.55 Hz
# [DETECTED] 2482.00s → Centroid: 9378.58 Hz, Bandwidth: 12251.28 Hz
# [DETECTED] 2483.50s → Centroid: 9485.81 Hz, Bandwidth: 12179.21 Hz
# [DETECTED] 2484.00s → Centroid: 9087.06 Hz, Bandwidth: 12043.94 Hz
# [DETECTED] 2485.00s → Centroid: 10261.34 Hz, Bandwidth: 12338.02 Hz
# [DETECTED] 2485.50s → Centroid: 9923.25 Hz, Bandwidth: 12162.51 Hz
# [DETECTED] 2486.00s → Centroid: 9175.80 Hz, Bandwidth: 11999.32 Hz
# [DETECTED] 2486.50s → Centroid: 10623.04 Hz, Bandwidth: 12309.80 Hz
# [DETECTED] 2487.50s → Centroid: 9739.87 Hz, Bandwidth: 12251.61 Hz
# [DETECTED] 2488.00s → Centroid: 10476.00 Hz, Bandwidth: 12196.85 Hz
# [DETECTED] 2488.50s → Centroid: 11427.53 Hz, Bandwidth: 12444.09 Hz
# [DETECTED] 2489.00s → Centroid: 10382.19 Hz, Bandwidth: 12328.97 Hz
# [DETECTED] 2489.50s → Centroid: 11869.97 Hz, Bandwidth: 12416.20 Hz
# [DETECTED] 2629.50s → Centroid: 11628.77 Hz, Bandwidth: 12320.79 Hz
# [DETECTED] 2636.50s → Centroid: 11679.59 Hz, Bandwidth: 12499.54 Hz
# [DETECTED] 2637.00s → Centroid: 10713.50 Hz, Bandwidth: 12406.81 Hz
# [DETECTED] 2637.50s → Centroid: 11432.97 Hz, Bandwidth: 12461.38 Hz
# [DETECTED] 2638.00s → Centroid: 11061.61 Hz, Bandwidth: 12440.83 Hz
# [DETECTED] 2638.50s → Centroid: 10631.54 Hz, Bandwidth: 12364.65 Hz
# [DETECTED] 2639.00s → Centroid: 11398.21 Hz, Bandwidth: 12496.61 Hz
# [DETECTED] 2640.00s → Centroid: 10757.94 Hz, Bandwidth: 12355.27 Hz
# [DETECTED] 2640.50s → Centroid: 10938.84 Hz, Bandwidth: 12389.81 Hz
# [DETECTED] 2641.00s → Centroid: 11276.94 Hz, Bandwidth: 12432.90 Hz
# [DETECTED] 2641.50s → Centroid: 11318.39 Hz, Bandwidth: 12397.52 Hz
# [DETECTED] 2642.00s → Centroid: 11045.19 Hz, Bandwidth: 12337.18 Hz
# [DETECTED] 2642.50s → Centroid: 10878.61 Hz, Bandwidth: 12274.38 Hz
# [DETECTED] 2643.00s → Centroid: 11320.81 Hz, Bandwidth: 12295.75 Hz
# [DETECTED] 2643.50s → Centroid: 10893.18 Hz, Bandwidth: 12274.37 Hz
# [DETECTED] 2644.00s → Centroid: 10744.78 Hz, Bandwidth: 12351.81 Hz
# [DETECTED] 2715.50s → Centroid: 11237.56 Hz, Bandwidth: 12160.49 Hz
# [DETECTED] 2716.00s → Centroid: 11332.31 Hz, Bandwidth: 12125.64 Hz
# [DETECTED] 2716.50s → Centroid: 11343.10 Hz, Bandwidth: 12144.29 Hz
# [DETECTED] 2717.00s → Centroid: 11098.53 Hz, Bandwidth: 12404.60 Hz
# [DETECTED] 2717.50s → Centroid: 11113.31 Hz, Bandwidth: 12330.79 Hz
# [DETECTED] 2718.00s → Centroid: 10901.85 Hz, Bandwidth: 11932.21 Hz
# [DETECTED] 2718.50s → Centroid: 10532.07 Hz, Bandwidth: 11674.87 Hz
# [DETECTED] 2719.00s → Centroid: 10316.60 Hz, Bandwidth: 11544.05 Hz
# [DETECTED] 2719.50s → Centroid: 10731.94 Hz, Bandwidth: 11781.08 Hz
# [DETECTED] 2720.00s → Centroid: 10787.92 Hz, Bandwidth: 11932.21 Hz
# [DETECTED] 2720.50s → Centroid: 10183.78 Hz, Bandwidth: 11861.42 Hz
# [DETECTED] 2721.00s → Centroid: 9720.47 Hz, Bandwidth: 11586.06 Hz
# [DETECTED] 2721.50s → Centroid: 9656.13 Hz, Bandwidth: 11231.25 Hz
# [DETECTED] 2722.00s → Centroid: 9818.67 Hz, Bandwidth: 11133.43 Hz
# [DETECTED] 2722.50s → Centroid: 10276.18 Hz, Bandwidth: 11216.40 Hz
# [DETECTED] 2723.00s → Centroid: 10434.46 Hz, Bandwidth: 11200.55 Hz
# [DETECTED] 2723.50s → Centroid: 10232.16 Hz, Bandwidth: 11076.00 Hz
# [DETECTED] 2725.00s → Centroid: 9752.97 Hz, Bandwidth: 11124.62 Hz
# [DETECTED] 2725.50s → Centroid: 9918.95 Hz, Bandwidth: 11297.52 Hz
# [DETECTED] 2726.00s → Centroid: 10113.97 Hz, Bandwidth: 11381.34 Hz
# [DETECTED] 2726.50s → Centroid: 9780.98 Hz, Bandwidth: 11484.28 Hz
# [DETECTED] 2727.00s → Centroid: 9817.73 Hz, Bandwidth: 11634.36 Hz
# [DETECTED] 2727.50s → Centroid: 9578.21 Hz, Bandwidth: 11455.76 Hz
# [DETECTED] 2728.00s → Centroid: 9351.24 Hz, Bandwidth: 11361.09 Hz
# [DETECTED] 2728.50s → Centroid: 9298.27 Hz, Bandwidth: 11410.72 Hz
# [DETECTED] 2730.50s → Centroid: 9643.24 Hz, Bandwidth: 11782.05 Hz
# ...
# [DETECTED] 10273.00s → Centroid: 10901.91 Hz, Bandwidth: 12183.97 Hz
# [DETECTED] 10273.50s → Centroid: 10533.50 Hz, Bandwidth: 12305.35 Hz
# [DETECTED] 10274.50s → Centroid: 10667.10 Hz, Bandwidth: 12258.09 Hz
# [DETECTED] 10281.50s → Centroid: 11321.76 Hz, Bandwidth: 12137.48 Hz
# [DETECTED] 10282.00s → Centroid: 11513.29 Hz, Bandwidth: 12366.93 Hz
# [DETECTED] 10288.50s → Centroid: 11635.89 Hz, Bandwidth: 12288.46 Hz
# [DETECTED] 10345.00s → Centroid: 11401.43 Hz, Bandwidth: 12247.39 Hz
# [DETECTED] 10345.50s → Centroid: 11575.56 Hz, Bandwidth: 12147.56 Hz
# [DETECTED] 10346.00s → Centroid: 11251.09 Hz, Bandwidth: 11935.69 Hz
# [DETECTED] 10346.50s → Centroid: 10609.29 Hz, Bandwidth: 12048.15 Hz
# [DETECTED] 10349.00s → Centroid: 11732.55 Hz, Bandwidth: 12284.17 Hz
# [DETECTED] 10350.50s → Centroid: 11992.15 Hz, Bandwidth: 12109.77 Hz
# [DETECTED] 10357.50s → Centroid: 11534.75 Hz, Bandwidth: 12372.80 Hz
# [DETECTED] 10358.00s → Centroid: 9198.13 Hz, Bandwidth: 11644.99 Hz
# [DETECTED] 10359.00s → Centroid: 10471.86 Hz, Bandwidth: 12444.78 Hz
# [DETECTED] 10360.50s → Centroid: 9736.03 Hz, Bandwidth: 12308.37 Hz
# [DETECTED] 10376.50s → Centroid: 10348.16 Hz, Bandwidth: 12041.96 Hz
# [DETECTED] 10398.00s → Centroid: 10066.41 Hz, Bandwidth: 11986.99 Hz
# [DETECTED] 10399.00s → Centroid: 9935.63 Hz, Bandwidth: 12351.37 Hz
# [DETECTED] 10400.50s → Centroid: 10280.49 Hz, Bandwidth: 11748.04 Hz
# [DETECTED] 10401.00s → Centroid: 9043.86 Hz, Bandwidth: 11626.48 Hz
# [DETECTED] 10403.00s → Centroid: 11820.42 Hz, Bandwidth: 12428.23 Hz
# [DETECTED] 10403.50s → Centroid: 9548.34 Hz, Bandwidth: 11487.70 Hz
# [DETECTED] 10404.00s → Centroid: 9291.95 Hz, Bandwidth: 11679.98 Hz
# [DETECTED] 10404.50s → Centroid: 9664.28 Hz, Bandwidth: 12336.68 Hz
# [DETECTED] 10405.50s → Centroid: 11708.91 Hz, Bandwidth: 12424.81 Hz
# [DETECTED] 10406.00s → Centroid: 9487.00 Hz, Bandwidth: 11539.72 Hz
# [DETECTED] 10406.50s → Centroid: 9200.65 Hz, Bandwidth: 11415.45 Hz
# [DETECTED] 10407.00s → Centroid: 9146.85 Hz, Bandwidth: 11212.73 Hz
# [DETECTED] 10407.50s → Centroid: 9936.95 Hz, Bandwidth: 11408.82 Hz
# [DETECTED] 10408.00s → Centroid: 11721.47 Hz, Bandwidth: 12446.29 Hz
# [DETECTED] 10410.50s → Centroid: 11815.05 Hz, Bandwidth: 12469.00 Hz
# [DETECTED] 10411.00s → Centroid: 11134.68 Hz, Bandwidth: 12485.17 Hz
# [DETECTED] 10414.50s → Centroid: 11680.15 Hz, Bandwidth: 12398.86 Hz
# [DETECTED] 10415.50s → Centroid: 11141.34 Hz, Bandwidth: 12029.31 Hz
# [DETECTED] 10416.00s → Centroid: 9747.47 Hz, Bandwidth: 11875.43 Hz
# [DETECTED] 10416.50s → Centroid: 10088.85 Hz, Bandwidth: 11997.61 Hz
# [DETECTED] 10417.00s → Centroid: 10615.68 Hz, Bandwidth: 11882.23 Hz
# [DETECTED] 10417.50s → Centroid: 11852.19 Hz, Bandwidth: 12313.47 Hz
# [DETECTED] 10418.00s → Centroid: 11099.77 Hz, Bandwidth: 12486.59 Hz
# [DETECTED] 10421.00s → Centroid: 10642.48 Hz, Bandwidth: 12269.42 Hz
# [DETECTED] 10421.50s → Centroid: 9837.01 Hz, Bandwidth: 11767.99 Hz
# [DETECTED] 10422.00s → Centroid: 9974.69 Hz, Bandwidth: 12038.52 Hz
# [DETECTED] 10423.50s → Centroid: 11155.13 Hz, Bandwidth: 12400.30 Hz
# [DETECTED] 10424.00s → Centroid: 10153.35 Hz, Bandwidth: 11900.22 Hz
# [DETECTED] 10424.50s → Centroid: 9842.97 Hz, Bandwidth: 11568.12 Hz
# [DETECTED] 10425.00s → Centroid: 9444.26 Hz, Bandwidth: 11567.58 Hz
# [DETECTED] 10425.50s → Centroid: 9891.85 Hz, Bandwidth: 11977.82 Hz
# [DETECTED] 10426.00s → Centroid: 10638.94 Hz, Bandwidth: 12108.96 Hz
# [DETECTED] 10426.50s → Centroid: 10627.02 Hz, Bandwidth: 11985.49 Hz
# [DETECTED] 10427.00s → Centroid: 9654.45 Hz, Bandwidth: 11819.01 Hz
# [DETECTED] 10427.50s → Centroid: 9948.10 Hz, Bandwidth: 11767.47 Hz
# [DETECTED] 10428.00s → Centroid: 10467.36 Hz, Bandwidth: 11898.23 Hz
# [DETECTED] 10428.50s → Centroid: 9951.21 Hz, Bandwidth: 11867.05 Hz
# [DETECTED] 10429.00s → Centroid: 10090.06 Hz, Bandwidth: 11839.13 Hz
# [DETECTED] 10429.50s → Centroid: 10338.96 Hz, Bandwidth: 11844.45 Hz
# [DETECTED] 10430.00s → Centroid: 9399.31 Hz, Bandwidth: 11645.82 Hz
# [DETECTED] 10430.50s → Centroid: 9825.86 Hz, Bandwidth: 11921.65 Hz
# [DETECTED] 10431.00s → Centroid: 10466.16 Hz, Bandwidth: 12121.56 Hz
# [DETECTED] 10431.50s → Centroid: 9127.63 Hz, Bandwidth: 11658.69 Hz
# [DETECTED] 10432.00s → Centroid: 9269.34 Hz, Bandwidth: 11736.25 Hz
# [DETECTED] 10432.50s → Centroid: 10349.52 Hz, Bandwidth: 12208.98 Hz
# [DETECTED] 10433.00s → Centroid: 9777.24 Hz, Bandwidth: 12098.25 Hz
# [DETECTED] 10433.50s → Centroid: 9553.86 Hz, Bandwidth: 11899.42 Hz
# [DETECTED] 10434.00s → Centroid: 10172.38 Hz, Bandwidth: 12145.35 Hz
# [DETECTED] 10434.50s → Centroid: 10090.66 Hz, Bandwidth: 12417.57 Hz
# [DETECTED] 10435.00s → Centroid: 9966.98 Hz, Bandwidth: 12331.51 Hz
# [DETECTED] 10435.50s → Centroid: 9744.12 Hz, Bandwidth: 12009.65 Hz
# [DETECTED] 10436.00s → Centroid: 9397.91 Hz, Bandwidth: 11749.84 Hz
# [DETECTED] 10516.50s → Centroid: 9800.30 Hz, Bandwidth: 11823.88 Hz
# [DETECTED] 10517.00s → Centroid: 9400.79 Hz, Bandwidth: 11797.67 Hz
# [DETECTED] 10517.50s → Centroid: 9200.78 Hz, Bandwidth: 11798.88 Hz
# [DETECTED] 10518.00s → Centroid: 9443.20 Hz, Bandwidth: 11909.88 Hz
# [DETECTED] 10518.50s → Centroid: 9388.72 Hz, Bandwidth: 11880.34 Hz
# [DETECTED] 10519.00s → Centroid: 9850.93 Hz, Bandwidth: 12004.63 Hz
# [DETECTED] 10519.50s → Centroid: 10041.03 Hz, Bandwidth: 12056.74 Hz
# [DETECTED] 10520.00s → Centroid: 9719.52 Hz, Bandwidth: 11965.29 Hz
# [DETECTED] 10520.50s → Centroid: 10039.87 Hz, Bandwidth: 11995.32 Hz
# [DETECTED] 10521.00s → Centroid: 9778.67 Hz, Bandwidth: 11829.06 Hz
# [DETECTED] 10521.50s → Centroid: 9308.80 Hz, Bandwidth: 11624.76 Hz
# [DETECTED] 10522.00s → Centroid: 9077.57 Hz, Bandwidth: 11181.42 Hz
# [DETECTED] 10525.00s → Centroid: 9068.77 Hz, Bandwidth: 11191.29 Hz
# [DETECTED] 10525.50s → Centroid: 9300.45 Hz, Bandwidth: 11210.08 Hz
# [DETECTED] 10526.00s → Centroid: 9371.96 Hz, Bandwidth: 11307.20 Hz
# [DETECTED] 10526.50s → Centroid: 9718.03 Hz, Bandwidth: 11515.43 Hz
# [DETECTED] 10527.00s → Centroid: 9663.35 Hz, Bandwidth: 11523.66 Hz
# [DETECTED] 10527.50s → Centroid: 9572.70 Hz, Bandwidth: 11472.90 Hz
# [DETECTED] 10528.00s → Centroid: 9661.21 Hz, Bandwidth: 11509.71 Hz
# [DETECTED] 10528.50s → Centroid: 10278.68 Hz, Bandwidth: 11683.20 Hz
# [DETECTED] 10529.00s → Centroid: 10204.63 Hz, Bandwidth: 11647.49 Hz
# [DETECTED] 10529.50s → Centroid: 9638.02 Hz, Bandwidth: 11516.08 Hz
# [DETECTED] 10530.00s → Centroid: 9526.72 Hz, Bandwidth: 11451.25 Hz
# [DETECTED] 10530.50s → Centroid: 9220.08 Hz, Bandwidth: 11220.51 Hz
# [DETECTED] 10533.00s → Centroid: 9120.43 Hz, Bandwidth: 11235.98 Hz
# [DETECTED] 10533.50s → Centroid: 9279.33 Hz, Bandwidth: 11262.45 Hz
# [DETECTED] 10534.50s → Centroid: 9472.35 Hz, Bandwidth: 11289.70 Hz
# [DETECTED] 10535.00s → Centroid: 9896.66 Hz, Bandwidth: 11438.56 Hz
# [DETECTED] 10535.50s → Centroid: 9746.15 Hz, Bandwidth: 11388.17 Hz
# [DETECTED] 10536.00s → Centroid: 9172.66 Hz, Bandwidth: 11166.80 Hz
# [DETECTED] 10538.50s → Centroid: 9591.59 Hz, Bandwidth: 11039.51 Hz
# [DETECTED] 10539.00s → Centroid: 9293.81 Hz, Bandwidth: 11091.33 Hz
# [DETECTED] 10539.50s → Centroid: 9166.28 Hz, Bandwidth: 11042.74 Hz
# [DETECTED] 10541.50s → Centroid: 9365.02 Hz, Bandwidth: 11016.44 Hz
# [DETECTED] 10592.00s → Centroid: 9078.68 Hz, Bandwidth: 11233.56 Hz
# [DETECTED] 10592.50s → Centroid: 9107.91 Hz, Bandwidth: 11261.38 Hz
# [DETECTED] 10594.00s → Centroid: 9017.67 Hz, Bandwidth: 11257.82 Hz
# [DETECTED] 10594.50s → Centroid: 9600.97 Hz, Bandwidth: 11490.21 Hz
# [DETECTED] 10595.00s → Centroid: 9119.93 Hz, Bandwidth: 11351.39 Hz
# [DETECTED] 10596.00s → Centroid: 9563.01 Hz, Bandwidth: 11505.56 Hz
# [DETECTED] 10596.50s → Centroid: 9758.72 Hz, Bandwidth: 11568.13 Hz
# [DETECTED] 10597.00s → Centroid: 9341.22 Hz, Bandwidth: 11601.29 Hz
# [DETECTED] 10597.50s → Centroid: 9530.07 Hz, Bandwidth: 11680.59 Hz
# [DETECTED] 10598.00s → Centroid: 9439.31 Hz, Bandwidth: 11825.37 Hz
# [DETECTED] 10598.50s → Centroid: 9570.85 Hz, Bandwidth: 11964.16 Hz
# [DETECTED] 10599.00s → Centroid: 10484.83 Hz, Bandwidth: 12154.41 Hz
# [DETECTED] 10599.50s → Centroid: 10293.25 Hz, Bandwidth: 12172.77 Hz
# [DETECTED] 10600.00s → Centroid: 10376.36 Hz, Bandwidth: 12216.00 Hz
# [DETECTED] 10600.50s → Centroid: 10661.07 Hz, Bandwidth: 12051.93 Hz
# [DETECTED] 10601.00s → Centroid: 10327.36 Hz, Bandwidth: 11787.38 Hz
# [DETECTED] 10601.50s → Centroid: 10191.90 Hz, Bandwidth: 12015.88 Hz
# [DETECTED] 10602.00s → Centroid: 11162.01 Hz, Bandwidth: 12381.73 Hz
# [DETECTED] 10603.00s → Centroid: 10676.26 Hz, Bandwidth: 12408.82 Hz
# [DETECTED] 10603.50s → Centroid: 10957.55 Hz, Bandwidth: 12250.09 Hz
# [DETECTED] 10604.00s → Centroid: 11878.99 Hz, Bandwidth: 12358.05 Hz
# [DETECTED] 10604.50s → Centroid: 9717.30 Hz, Bandwidth: 11686.13 Hz
# [DETECTED] 10605.00s → Centroid: 9145.87 Hz, Bandwidth: 11589.86 Hz
# [DETECTED] 10605.50s → Centroid: 10957.33 Hz, Bandwidth: 12359.05 Hz
# [DETECTED] 10606.00s → Centroid: 11025.58 Hz, Bandwidth: 12344.25 Hz
# [DETECTED] 10606.50s → Centroid: 11401.91 Hz, Bandwidth: 12383.84 Hz
# [DETECTED] 10617.50s → Centroid: 9835.59 Hz, Bandwidth: 12420.52 Hz
# [DETECTED] 10621.00s → Centroid: 10923.20 Hz, Bandwidth: 12400.15 Hz
# [DETECTED] 10621.50s → Centroid: 10266.52 Hz, Bandwidth: 12293.05 Hz
# [DETECTED] 10624.50s → Centroid: 9115.61 Hz, Bandwidth: 12132.50 Hz
# [DETECTED] 10625.00s → Centroid: 9847.33 Hz, Bandwidth: 12478.95 Hz
# [DETECTED] 10657.50s → Centroid: 9533.10 Hz, Bandwidth: 11824.49 Hz
# [DETECTED] 10658.00s → Centroid: 9971.45 Hz, Bandwidth: 12107.42 Hz
# [DETECTED] 10667.50s → Centroid: 10901.35 Hz, Bandwidth: 12303.72 Hz
# [DETECTED] 10668.00s → Centroid: 9068.41 Hz, Bandwidth: 11317.79 Hz
# [DETECTED] 10676.00s → Centroid: 9230.40 Hz, Bandwidth: 11597.46 Hz
# [DETECTED] 10676.50s → Centroid: 10042.89 Hz, Bandwidth: 11905.70 Hz
# [DETECTED] 10677.00s → Centroid: 9506.66 Hz, Bandwidth: 11989.92 Hz
# [DETECTED] 10677.50s → Centroid: 9016.27 Hz, Bandwidth: 11910.01 Hz
# [DETECTED] 10678.00s → Centroid: 9483.19 Hz, Bandwidth: 12045.41 Hz
# [DETECTED] 10678.50s → Centroid: 9918.59 Hz, Bandwidth: 12060.02 Hz
# [DETECTED] 10679.00s → Centroid: 10662.46 Hz, Bandwidth: 11877.07 Hz
# [DETECTED] 10679.50s → Centroid: 10005.64 Hz, Bandwidth: 11164.80 Hz
# [DETECTED] 10681.50s → Centroid: 9626.36 Hz, Bandwidth: 11966.23 Hz
# [DETECTED] 10683.50s → Centroid: 10308.03 Hz, Bandwidth: 12483.83 Hz
# [DETECTED] 10684.00s → Centroid: 9604.12 Hz, Bandwidth: 12101.63 Hz
# [DETECTED] 10685.00s → Centroid: 9811.70 Hz, Bandwidth: 12196.70 Hz
# [DETECTED] 10685.50s → Centroid: 10472.16 Hz, Bandwidth: 12474.41 Hz
# [DETECTED] 10686.00s → Centroid: 9860.88 Hz, Bandwidth: 12494.32 Hz
# [DETECTED] 10687.50s → Centroid: 10153.03 Hz, Bandwidth: 11852.29 Hz
# [DETECTED] 10689.50s → Centroid: 9656.28 Hz, Bandwidth: 12045.40 Hz
# [DETECTED] 10693.00s → Centroid: 11092.92 Hz, Bandwidth: 12443.87 Hz
# [DETECTED] 10693.50s → Centroid: 11462.24 Hz, Bandwidth: 12306.63 Hz
# [DETECTED] 10694.00s → Centroid: 11159.20 Hz, Bandwidth: 12456.62 Hz
# [DETECTED] 10694.50s → Centroid: 9632.11 Hz, Bandwidth: 11851.60 Hz
# [DETECTED] 10695.00s → Centroid: 9608.33 Hz, Bandwidth: 11738.45 Hz
# [DETECTED] 10695.50s → Centroid: 10718.76 Hz, Bandwidth: 12185.03 Hz
# [DETECTED] 10698.00s → Centroid: 11075.90 Hz, Bandwidth: 11969.44 Hz
# [DETECTED] 10698.50s → Centroid: 11134.84 Hz, Bandwidth: 12293.88 Hz
# [DETECTED] 10700.00s → Centroid: 11683.80 Hz, Bandwidth: 12173.25 Hz
# [DETECTED] 10700.50s → Centroid: 11414.74 Hz, Bandwidth: 12096.40 Hz
# [DETECTED] 10701.50s → Centroid: 11856.08 Hz, Bandwidth: 12094.51 Hz
# [DETECTED] 10702.00s → Centroid: 11967.66 Hz, Bandwidth: 11970.79 Hz
# [DETECTED] 10702.50s → Centroid: 11979.02 Hz, Bandwidth: 11898.85 Hz
# [DETECTED] 10703.00s → Centroid: 10912.57 Hz, Bandwidth: 11750.98 Hz
# [DETECTED] 10703.50s → Centroid: 11218.18 Hz, Bandwidth: 12001.65 Hz
# [DETECTED] 10705.50s → Centroid: 11965.67 Hz, Bandwidth: 12218.01 Hz
# [DETECTED] 10707.00s → Centroid: 11159.05 Hz, Bandwidth: 11539.39 Hz
# [DETECTED] 10707.50s → Centroid: 9915.37 Hz, Bandwidth: 11445.31 Hz
# [DETECTED] 10708.00s → Centroid: 10619.07 Hz, Bandwidth: 11945.71 Hz
# [DETECTED] 10712.00s → Centroid: 11610.55 Hz, Bandwidth: 11670.84 Hz
# [DETECTED] 10716.00s → Centroid: 11699.13 Hz, Bandwidth: 11938.89 Hz
# [DETECTED] 10719.50s → Centroid: 11175.95 Hz, Bandwidth: 11799.36 Hz
# [DETECTED] 10720.00s → Centroid: 9044.54 Hz, Bandwidth: 11079.46 Hz
# [DETECTED] 10721.00s → Centroid: 10796.62 Hz, Bandwidth: 11751.73 Hz
# [DETECTED] 10722.00s → Centroid: 10862.07 Hz, Bandwidth: 11697.69 Hz
# [DETECTED] 10722.50s → Centroid: 10276.19 Hz, Bandwidth: 11559.40 Hz
# [DETECTED] 10723.00s → Centroid: 11949.47 Hz, Bandwidth: 12089.34 Hz
# [DETECTED] 10723.50s → Centroid: 11629.04 Hz, Bandwidth: 12259.05 Hz
# [DETECTED] 10724.00s → Centroid: 11369.63 Hz, Bandwidth: 12277.52 Hz
# [DETECTED] 10724.50s → Centroid: 11200.97 Hz, Bandwidth: 12215.76 Hz
# [DETECTED] 10725.00s → Centroid: 11792.74 Hz, Bandwidth: 12461.84 Hz
# [DETECTED] 10726.00s → Centroid: 11170.78 Hz, Bandwidth: 12172.38 Hz
# [DETECTED] 10726.50s → Centroid: 10621.31 Hz, Bandwidth: 12088.18 Hz
# [DETECTED] 10727.00s → Centroid: 11497.56 Hz, Bandwidth: 12158.97 Hz
# [DETECTED] 10727.50s → Centroid: 10595.92 Hz, Bandwidth: 12191.02 Hz
# [DETECTED] 10728.00s → Centroid: 11048.30 Hz, Bandwidth: 12363.19 Hz
# [DETECTED] 10729.00s → Centroid: 11186.34 Hz, Bandwidth: 12415.21 Hz
# [DETECTED] 10729.50s → Centroid: 11855.11 Hz, Bandwidth: 12251.33 Hz
# [DETECTED] 10730.50s → Centroid: 10808.00 Hz, Bandwidth: 11811.37 Hz
# [DETECTED] 10731.00s → Centroid: 11053.33 Hz, Bandwidth: 12209.07 Hz
# [DETECTED] 10731.50s → Centroid: 10738.87 Hz, Bandwidth: 12478.40 Hz
# [DETECTED] 10732.00s → Centroid: 9043.39 Hz, Bandwidth: 12058.69 Hz
# [DETECTED] 10732.50s → Centroid: 10367.27 Hz, Bandwidth: 12391.31 Hz
# [DETECTED] 10733.00s → Centroid: 10497.78 Hz, Bandwidth: 12295.34 Hz
# [DETECTED] 10733.50s → Centroid: 10163.72 Hz, Bandwidth: 12020.84 Hz
# [DETECTED] 10734.00s → Centroid: 11358.71 Hz, Bandwidth: 12356.33 Hz
# [DETECTED] 10734.50s → Centroid: 10655.78 Hz, Bandwidth: 12283.95 Hz
# [DETECTED] 10735.00s → Centroid: 11121.52 Hz, Bandwidth: 12422.67 Hz
# [DETECTED] 10736.00s → Centroid: 10739.74 Hz, Bandwidth: 12317.94 Hz
# [DETECTED] 10737.50s → Centroid: 10298.01 Hz, Bandwidth: 11996.98 Hz
# [DETECTED] 10738.00s → Centroid: 10767.99 Hz, Bandwidth: 12084.74 Hz
# [DETECTED] 10739.00s → Centroid: 9865.94 Hz, Bandwidth: 11474.21 Hz
# [DETECTED] 10739.50s → Centroid: 9111.95 Hz, Bandwidth: 11444.30 Hz
# [DETECTED] 10740.00s → Centroid: 10911.81 Hz, Bandwidth: 12331.81 Hz
# [DETECTED] 10741.00s → Centroid: 11926.13 Hz, Bandwidth: 12255.21 Hz
# [DETECTED] 10741.50s → Centroid: 11145.52 Hz, Bandwidth: 12456.47 Hz
# [DETECTED] 10742.00s → Centroid: 11917.27 Hz, Bandwidth: 12317.88 Hz
# [DETECTED] 10742.50s → Centroid: 11546.22 Hz, Bandwidth: 12124.91 Hz
# [DETECTED] 10743.00s → Centroid: 11121.28 Hz, Bandwidth: 12088.45 Hz
# [DETECTED] 10743.50s → Centroid: 11747.53 Hz, Bandwidth: 12068.81 Hz
# [DETECTED] 10744.00s → Centroid: 11234.07 Hz, Bandwidth: 12278.92 Hz
# [DETECTED] 10744.50s → Centroid: 11436.69 Hz, Bandwidth: 12282.99 Hz
# [DETECTED] 10748.50s → Centroid: 11613.80 Hz, Bandwidth: 12495.04 Hz
# [DETECTED] 10749.50s → Centroid: 11528.47 Hz, Bandwidth: 11791.88 Hz
# [DETECTED] 10750.00s → Centroid: 9455.95 Hz, Bandwidth: 11221.88 Hz
# [DETECTED] 10750.50s → Centroid: 10532.33 Hz, Bandwidth: 11884.20 Hz
# [DETECTED] 10756.50s → Centroid: 11843.59 Hz, Bandwidth: 12033.79 Hz
# [DETECTED] 10757.00s → Centroid: 10881.61 Hz, Bandwidth: 12193.17 Hz
# [DETECTED] 10777.50s → Centroid: 9394.09 Hz, Bandwidth: 11847.78 Hz
# [DETECTED] 10778.00s → Centroid: 10111.86 Hz, Bandwidth: 12296.26 Hz
# [DETECTED] 10779.50s → Centroid: 11101.73 Hz, Bandwidth: 12499.27 Hz
# [DETECTED] 10780.00s → Centroid: 11545.40 Hz, Bandwidth: 12398.08 Hz
# [DETECTED] 10780.50s → Centroid: 11742.68 Hz, Bandwidth: 12390.05 Hz
# [DETECTED] 10781.00s → Centroid: 9358.58 Hz, Bandwidth: 11984.54 Hz
# [DETECTED] 10781.50s → Centroid: 9864.85 Hz, Bandwidth: 12266.29 Hz
# [DETECTED] 10783.50s → Centroid: 9884.11 Hz, Bandwidth: 12333.47 Hz
# [DETECTED] 10786.50s → Centroid: 9543.12 Hz, Bandwidth: 12292.87 Hz
# Detected 1375 events
# Saved 1375 5-second clips and XMLs to /content/drive/MyDrive/lake-sounds/clips

# %%
# --- XML time extraction ---
def parse_xml_time(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()
    for proc_event in root.findall(".//PROC_EVENT"):
        wav_handler = proc_event.find("WavFileHandler")
        if wav_handler is not None:
            time_str = wav_handler.attrib.get("SamplingStartTimeLocal")
            if time_str:
                return datetime.fromisoformat(time_str)
    raise ValueError(f"Time not found in {xml_path}")

def write_xml_for_clip(base_datetime, clip_start, output_path):
    clip_time = base_datetime + timedelta(seconds=clip_start)
    root = ET.Element("ST")
    proc_event = ET.SubElement(root, "PROC_EVENT", attrib={"ID": "4"})
    ET.SubElement(proc_event, "WavFileHandler", attrib={
        "SamplingStartTimeLocal": clip_time.isoformat()
    })
    tree = ET.ElementTree(root)
    tree.write(output_path)

# --- Spectral-based detector ---
def detect_events_by_spectral_features(audio, sr):
    if audio.ndim > 1:
        audio = np.mean(audio, axis=1)

    frame_len = int(sr * 0.1)
    hop_len = int(sr * 0.05)

    centroid = librosa.feature.spectral_centroid(y=audio, sr=sr, n_fft=frame_len, hop_length=hop_len)[0]
    bandwidth = librosa.feature.spectral_bandwidth(y=audio, sr=sr, n_fft=frame_len, hop_length=hop_len)[0]

    times = librosa.frames_to_time(np.arange(len(centroid)), sr=sr, hop_length=hop_len)

    is_event = (centroid > CENTROID_THRESHOLD_HZ) & (bandwidth > BANDWIDTH_THRESHOLD_HZ)

    events = []
    start = None
    for i, val in enumerate(is_event):
        if val and start is None:
            start = times[i]
        elif not val and start is not None:
            end = times[i]
            if end - start > MIN_SILENCE_DURATION:
                events.append((start, end))
            start = None
    if start is not None:
        events.append((start, times[-1]))

    return events

# %%
def process_file(wav_path, xml_path, chunk_duration=60, overlap=5):
    print(f"\n▶️ Processing {os.path.basename(wav_path)}")
    base_time = parse_xml_time(xml_path)

    with sf.SoundFile(wav_path) as f:
        sr = f.samplerate
        total_samples = len(f)
        chunk_samples = int(chunk_duration * sr)
        hop_samples = chunk_samples - int(overlap * sr)

    events_all = []

    with sf.SoundFile(wav_path) as f:
        for start_sample in range(0, total_samples, hop_samples):
            f.seek(start_sample)
            samples_to_read = min(chunk_samples, total_samples - start_sample)
            chunk = f.read(samples_to_read)
            if chunk.ndim > 1:
                chunk = np.mean(chunk, axis=1)

            events = detect_events_by_spectral_features(chunk, sr)

            for start, end in events:
                abs_start = (start_sample / sr) + start
                abs_end = (start_sample / sr) + end

                if not events_all or abs_start > events_all[-1][1]:
                    events_all.append([abs_start, abs_end])
                else:
                    events_all[-1][1] = max(events_all[-1][1], abs_end)

    print(f"✅ {len(events_all)} spectral events found")

    audio_seg = AudioSegment.from_file(wav_path)
    base_name = os.path.splitext(os.path.basename(wav_path))[0]

    for i, (start, end) in enumerate(events_all):
        duration = end - start
        n_clips = int(np.ceil(duration / CLIP_LENGTH))
        for j in range(n_clips):
            clip_start = start + j * CLIP_LENGTH
            clip_ms = int(clip_start * 1000)
            clip = audio_seg[clip_ms: clip_ms + CLIP_LENGTH * 1000]

            suffix = f"{base_name}_spec{i+1}_{j+1}of{n_clips}"
            wav_out = os.path.join(OUTPUT_DIR, f"{suffix}.wav")
            xml_out = os.path.join(OUTPUT_DIR, f"{suffix}.xml")

            clip.export(wav_out, format="wav")
            write_xml_for_clip(base_time, clip_start, xml_out)

# --- Main ---
for fname in os.listdir(WAV_DIR):
    if fname.endswith(".wav"):
        wav_file = os.path.join(WAV_DIR, fname)
        xml_file = os.path.join(WAV_DIR, fname.replace(".wav", ".log.xml"))
        if os.path.exists(xml_file):
            process_file(wav_file, xml_file)
# Out:
# ▶️ Processing 8567.240831110000.wav
# ✅ 1 spectral events found
